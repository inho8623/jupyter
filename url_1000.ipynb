# %%
import urllib.request


url = 'https://academic.naver.com/article.naver?doc_id=597939061'
res = urllib.request.urlopen(url)
print(res.status)
url = 'https://academic.naver.com/article.naver?doc_id=560008958'
res = urllib.request.urlopen(url)
print(res.status)
url = 'https://academic.naver.com/article.naver?doc_id=597939089'
res = urllib.request.urlopen(url)
print(res.status)
url = 'https://academic.naver.com/article.naver?doc_id=597938960'
res = urllib.request.urlopen(url)
print(res.status)
url = 'https://academic.naver.com/article.naver?doc_id=597938953'
res = urllib.request.urlopen(url)
print(res.status)
url = 'https://academic.naver.com/article.naver?doc_id=597939034'
res = urllib.request.urlopen(url)
print(res.status)
url = 'https://academic.naver.com/article.naver?doc_id=597938953'
res = urllib.request.urlopen(url)
print(res.status)
url = 'https://academic.naver.com/article.naver?doc_id=560009003'
res = urllib.request.urlopen(url)
print(res.status)
url = 'https://academic.naver.com/article.naver?doc_id=597939010'
res = urllib.request.urlopen(url)
print(res.status)
url = 'https://academic.naver.com/article.naver?doc_id=597938949'
res = urllib.request.urlopen(url)
print(res.status)
url = 'https://academic.naver.com/article.naver?doc_id=560008978'
res = urllib.request.urlopen(url)
print(res.status)
url = 'https://academic.naver.com/article.naver?doc_id=597939027'
res = urllib.request.urlopen(url)
print(res.status)
url = 'https://academic.naver.com/article.naver?doc_id=597939027'
res = urllib.request.urlopen(url)
print(res.status)
url = 'https://academic.naver.com/article.naver?doc_id=597939002'
res = urllib.request.urlopen(url)
print(res.status)
url = 'https://academic.naver.com/article.naver?doc_id=597939068'
res = urllib.request.urlopen(url)
print(res.status)
url = 'https://academic.naver.com/article.naver?doc_id=560008987'
res = urllib.request.urlopen(url)
print(res.status)
url = 'https://academic.naver.com/article.naver?doc_id=597939074'
res = urllib.request.urlopen(url)
print(res.status)
url = 'https://academic.naver.com/article.naver?doc_id=597939050'
res = urllib.request.urlopen(url)
print(res.status)
url = 'https://academic.naver.com/article.naver?doc_id=560008991'
res = urllib.request.urlopen(url)
print(res.status)
url = 'https://academic.naver.com/article.naver?doc_id=597939085'
res = urllib.request.urlopen(url)
print(res.status)
url = 'https://academic.naver.com/article.naver?doc_id=560008955'
res = urllib.request.urlopen(url)
print(res.status)
url = 'https://academic.naver.com/article.naver?doc_id=597939063'
res = urllib.request.urlopen(url)
print(res.status)
url = 'https://academic.naver.com/article.naver?doc_id=597939033'
res = urllib.request.urlopen(url)
print(res.status)
url = 'https://academic.naver.com/article.naver?doc_id=597938952'
res = urllib.request.urlopen(url)
print(res.status)
url = 'https://academic.naver.com/article.naver?doc_id=597938986'
res = urllib.request.urlopen(url)
print(res.status)
url = 'https://academic.naver.com/article.naver?doc_id=597939048'
res = urllib.request.urlopen(url)
print(res.status)
url = 'https://academic.naver.com/article.naver?doc_id=597939015'
res = urllib.request.urlopen(url)
print(res.status)
url = 'https://academic.naver.com/article.naver?doc_id=597938998'
res = urllib.request.urlopen(url)
print(res.status)
url = 'https://academic.naver.com/article.naver?doc_id=560008985'
res = urllib.request.urlopen(url)
print(res.status)
url = 'https://academic.naver.com/article.naver?doc_id=597938979'
res = urllib.request.urlopen(url)
print(res.status)
url = 'https://academic.naver.com/article.naver?doc_id=560008975'
res = urllib.request.urlopen(url)
print(res.status)
url = 'https://academic.naver.com/article.naver?doc_id=597939061'
res = urllib.request.urlopen(url)
print(res.status)
url = 'https://academic.naver.com/article.naver?doc_id=560008958'
res = urllib.request.urlopen(url)
print(res.status)
url = 'https://academic.naver.com/article.naver?doc_id=597939089'
res = urllib.request.urlopen(url)
print(res.status)
url = 'https://academic.naver.com/article.naver?doc_id=597938960'
res = urllib.request.urlopen(url)
print(res.status)
url = 'https://academic.naver.com/article.naver?doc_id=597938953'
res = urllib.request.urlopen(url)
print(res.status)
url = 'https://academic.naver.com/article.naver?doc_id=597939034'
res = urllib.request.urlopen(url)
print(res.status)
url = 'https://academic.naver.com/article.naver?doc_id=597938953'
res = urllib.request.urlopen(url)
print(res.status)
url = 'https://academic.naver.com/article.naver?doc_id=560009003'
res = urllib.request.urlopen(url)
print(res.status)
url = 'https://academic.naver.com/article.naver?doc_id=597939010'
res = urllib.request.urlopen(url)
print(res.status)
url = 'https://academic.naver.com/article.naver?doc_id=597938949'
res = urllib.request.urlopen(url)
print(res.status)
url = 'https://academic.naver.com/article.naver?doc_id=560008978'
res = urllib.request.urlopen(url)
print(res.status)
url = 'https://academic.naver.com/article.naver?doc_id=597939027'
res = urllib.request.urlopen(url)
print(res.status)
url = 'https://academic.naver.com/article.naver?doc_id=597939027'
res = urllib.request.urlopen(url)
print(res.status)
url = 'https://academic.naver.com/article.naver?doc_id=597939002'
res = urllib.request.urlopen(url)
print(res.status)
url = 'https://academic.naver.com/article.naver?doc_id=597939068'
res = urllib.request.urlopen(url)
print(res.status)
url = 'https://academic.naver.com/article.naver?doc_id=560008987'
res = urllib.request.urlopen(url)
print(res.status)
url = 'https://academic.naver.com/article.naver?doc_id=597939074'
res = urllib.request.urlopen(url)
print(res.status)
url = 'https://academic.naver.com/article.naver?doc_id=597939050'
res = urllib.request.urlopen(url)
print(res.status)
url = 'https://academic.naver.com/article.naver?doc_id=560008991'
res = urllib.request.urlopen(url)
print(res.status)
url = 'https://academic.naver.com/article.naver?doc_id=597939085'
res = urllib.request.urlopen(url)
print(res.status)
url = 'https://academic.naver.com/article.naver?doc_id=560008955'
res = urllib.request.urlopen(url)
print(res.status)
url = 'https://academic.naver.com/article.naver?doc_id=597939063'
res = urllib.request.urlopen(url)
print(res.status)
url = 'https://academic.naver.com/article.naver?doc_id=597939033'
res = urllib.request.urlopen(url)
print(res.status)
url = 'https://academic.naver.com/article.naver?doc_id=597938952'
res = urllib.request.urlopen(url)
print(res.status)
url = 'https://academic.naver.com/article.naver?doc_id=597938986'
res = urllib.request.urlopen(url)
print(res.status)
url = 'https://academic.naver.com/article.naver?doc_id=597939048'
res = urllib.request.urlopen(url)
print(res.status)
url = 'https://academic.naver.com/article.naver?doc_id=597939015'
res = urllib.request.urlopen(url)
print(res.status)
url = 'https://academic.naver.com/article.naver?doc_id=597938998'
res = urllib.request.urlopen(url)
print(res.status)
url = 'https://academic.naver.com/article.naver?doc_id=560008985'
res = urllib.request.urlopen(url)
print(res.status)
url = 'https://academic.naver.com/article.naver?doc_id=597938979'
res = urllib.request.urlopen(url)
print(res.status)
url = 'https://academic.naver.com/article.naver?doc_id=560008975'
res = urllib.request.urlopen(url)
print(res.status)
url = 'https://academic.naver.com/article.naver?doc_id=597939061'
res = urllib.request.urlopen(url)
print(res.status)
url = 'https://academic.naver.com/article.naver?doc_id=560008958'
res = urllib.request.urlopen(url)
print(res.status)
url = 'https://academic.naver.com/article.naver?doc_id=597939089'
res = urllib.request.urlopen(url)
print(res.status)
url = 'https://academic.naver.com/article.naver?doc_id=597938960'
res = urllib.request.urlopen(url)
print(res.status)
url = 'https://academic.naver.com/article.naver?doc_id=597938953'
res = urllib.request.urlopen(url)
print(res.status)
url = 'https://academic.naver.com/article.naver?doc_id=597939034'
res = urllib.request.urlopen(url)
print(res.status)
url = 'https://academic.naver.com/article.naver?doc_id=597938953'
res = urllib.request.urlopen(url)
print(res.status)
url = 'https://academic.naver.com/article.naver?doc_id=560009003'
res = urllib.request.urlopen(url)
print(res.status)
url = 'https://academic.naver.com/article.naver?doc_id=597939010'
res = urllib.request.urlopen(url)
print(res.status)
url = 'https://academic.naver.com/article.naver?doc_id=597938949'
res = urllib.request.urlopen(url)
print(res.status)
url = 'https://academic.naver.com/article.naver?doc_id=560008978'
res = urllib.request.urlopen(url)
print(res.status)
url = 'https://academic.naver.com/article.naver?doc_id=597939027'
res = urllib.request.urlopen(url)
print(res.status)
url = 'https://academic.naver.com/article.naver?doc_id=597939027'
res = urllib.request.urlopen(url)
print(res.status)
url = 'https://academic.naver.com/article.naver?doc_id=597939002'
res = urllib.request.urlopen(url)
print(res.status)
url = 'https://academic.naver.com/article.naver?doc_id=597939068'
res = urllib.request.urlopen(url)
print(res.status)
url = 'https://academic.naver.com/article.naver?doc_id=560008987'
res = urllib.request.urlopen(url)
print(res.status)
url = 'https://academic.naver.com/article.naver?doc_id=597939074'
res = urllib.request.urlopen(url)
print(res.status)
url = 'https://academic.naver.com/article.naver?doc_id=597939050'
res = urllib.request.urlopen(url)
print(res.status)
url = 'https://academic.naver.com/article.naver?doc_id=560008991'
res = urllib.request.urlopen(url)
print(res.status)
url = 'https://academic.naver.com/article.naver?doc_id=597939085'
res = urllib.request.urlopen(url)
print(res.status)
url = 'https://academic.naver.com/article.naver?doc_id=560008955'
res = urllib.request.urlopen(url)
print(res.status)
url = 'https://academic.naver.com/article.naver?doc_id=597939063'
res = urllib.request.urlopen(url)
print(res.status)
url = 'https://academic.naver.com/article.naver?doc_id=597939033'
res = urllib.request.urlopen(url)
print(res.status)
url = 'https://academic.naver.com/article.naver?doc_id=597938952'
res = urllib.request.urlopen(url)
print(res.status)
url = 'https://academic.naver.com/article.naver?doc_id=597938986'
res = urllib.request.urlopen(url)
print(res.status)
url = 'https://academic.naver.com/article.naver?doc_id=597939048'
res = urllib.request.urlopen(url)
print(res.status)
url = 'https://academic.naver.com/article.naver?doc_id=597939015'
res = urllib.request.urlopen(url)
print(res.status)
url = 'https://academic.naver.com/article.naver?doc_id=597938998'
res = urllib.request.urlopen(url)
print(res.status)
url = 'https://academic.naver.com/article.naver?doc_id=560008985'
res = urllib.request.urlopen(url)
print(res.status)
url = 'https://academic.naver.com/article.naver?doc_id=597938979'
res = urllib.request.urlopen(url)
print(res.status)
url = 'https://academic.naver.com/article.naver?doc_id=560008975'
res = urllib.request.urlopen(url)
print(res.status)
url = 'https://academic.naver.com/article.naver?doc_id=597939061'
res = urllib.request.urlopen(url)
print(res.status)
url = 'https://academic.naver.com/article.naver?doc_id=560008958'
res = urllib.request.urlopen(url)
print(res.status)
url = 'https://academic.naver.com/article.naver?doc_id=597939089'
res = urllib.request.urlopen(url)
print(res.status)
url = 'https://academic.naver.com/article.naver?doc_id=597938960'
res = urllib.request.urlopen(url)
print(res.status)
url = 'https://academic.naver.com/article.naver?doc_id=597938953'
res = urllib.request.urlopen(url)
print(res.status)
url = 'https://academic.naver.com/article.naver?doc_id=597939034'
res = urllib.request.urlopen(url)
print(res.status)
url = 'https://academic.naver.com/article.naver?doc_id=597938953'
res = urllib.request.urlopen(url)
print(res.status)
url = 'https://academic.naver.com/article.naver?doc_id=560009003'
res = urllib.request.urlopen(url)
print(res.status)
url = 'https://academic.naver.com/article.naver?doc_id=597939010'
res = urllib.request.urlopen(url)
print(res.status)
url = 'https://academic.naver.com/article.naver?doc_id=597938949'
res = urllib.request.urlopen(url)
print(res.status)
url = 'https://academic.naver.com/article.naver?doc_id=560008978'
res = urllib.request.urlopen(url)
print(res.status)
url = 'https://academic.naver.com/article.naver?doc_id=597939027'
res = urllib.request.urlopen(url)
print(res.status)
url = 'https://academic.naver.com/article.naver?doc_id=597939027'
res = urllib.request.urlopen(url)
print(res.status)
url = 'https://academic.naver.com/article.naver?doc_id=597939002'
res = urllib.request.urlopen(url)
print(res.status)
url = 'https://academic.naver.com/article.naver?doc_id=597939068'
res = urllib.request.urlopen(url)
print(res.status)
url = 'https://academic.naver.com/article.naver?doc_id=560008987'
res = urllib.request.urlopen(url)
print(res.status)
url = 'https://academic.naver.com/article.naver?doc_id=597939074'
res = urllib.request.urlopen(url)
print(res.status)
url = 'https://academic.naver.com/article.naver?doc_id=597939050'
res = urllib.request.urlopen(url)
print(res.status)
url = 'https://academic.naver.com/article.naver?doc_id=560008991'
res = urllib.request.urlopen(url)
print(res.status)
url = 'https://academic.naver.com/article.naver?doc_id=597939085'
res = urllib.request.urlopen(url)
print(res.status)
url = 'https://academic.naver.com/article.naver?doc_id=560008955'
res = urllib.request.urlopen(url)
print(res.status)
url = 'https://academic.naver.com/article.naver?doc_id=597939063'
res = urllib.request.urlopen(url)
print(res.status)
url = 'https://academic.naver.com/article.naver?doc_id=597939033'
res = urllib.request.urlopen(url)
print(res.status)
url = 'https://academic.naver.com/article.naver?doc_id=597938952'
res = urllib.request.urlopen(url)
print(res.status)
url = 'https://academic.naver.com/article.naver?doc_id=597938986'
res = urllib.request.urlopen(url)
print(res.status)
url = 'https://academic.naver.com/article.naver?doc_id=597939048'
res = urllib.request.urlopen(url)
print(res.status)
url = 'https://academic.naver.com/article.naver?doc_id=597939015'
res = urllib.request.urlopen(url)
print(res.status)
url = 'https://academic.naver.com/article.naver?doc_id=597938998'
res = urllib.request.urlopen(url)
print(res.status)
url = 'https://academic.naver.com/article.naver?doc_id=560008985'
res = urllib.request.urlopen(url)
print(res.status)
url = 'https://academic.naver.com/article.naver?doc_id=597938979'
res = urllib.request.urlopen(url)
print(res.status)
url = 'https://academic.naver.com/article.naver?doc_id=560008975'
res = urllib.request.urlopen(url)
print(res.status)
url = 'https://academic.naver.com/article.naver?doc_id=597939061'
res = urllib.request.urlopen(url)
print(res.status)
url = 'https://academic.naver.com/article.naver?doc_id=560008958'
res = urllib.request.urlopen(url)
print(res.status)
url = 'https://academic.naver.com/article.naver?doc_id=597939089'
res = urllib.request.urlopen(url)
print(res.status)
url = 'https://academic.naver.com/article.naver?doc_id=597938960'
res = urllib.request.urlopen(url)
print(res.status)
url = 'https://academic.naver.com/article.naver?doc_id=597938953'
res = urllib.request.urlopen(url)
print(res.status)
url = 'https://academic.naver.com/article.naver?doc_id=597939034'
res = urllib.request.urlopen(url)
print(res.status)
url = 'https://academic.naver.com/article.naver?doc_id=597938953'
res = urllib.request.urlopen(url)
print(res.status)
url = 'https://academic.naver.com/article.naver?doc_id=560009003'
res = urllib.request.urlopen(url)
print(res.status)
url = 'https://academic.naver.com/article.naver?doc_id=597939010'
res = urllib.request.urlopen(url)
print(res.status)
url = 'https://academic.naver.com/article.naver?doc_id=597938949'
res = urllib.request.urlopen(url)
print(res.status)
url = 'https://academic.naver.com/article.naver?doc_id=560008978'
res = urllib.request.urlopen(url)
print(res.status)
url = 'https://academic.naver.com/article.naver?doc_id=597939027'
res = urllib.request.urlopen(url)
print(res.status)
url = 'https://academic.naver.com/article.naver?doc_id=597939027'
res = urllib.request.urlopen(url)
print(res.status)
url = 'https://academic.naver.com/article.naver?doc_id=597939002'
res = urllib.request.urlopen(url)
print(res.status)
url = 'https://academic.naver.com/article.naver?doc_id=597939068'
res = urllib.request.urlopen(url)
print(res.status)
url = 'https://academic.naver.com/article.naver?doc_id=560008987'
res = urllib.request.urlopen(url)
print(res.status)
url = 'https://academic.naver.com/article.naver?doc_id=597939074'
res = urllib.request.urlopen(url)
print(res.status)
url = 'https://academic.naver.com/article.naver?doc_id=597939050'
res = urllib.request.urlopen(url)
print(res.status)
url = 'https://academic.naver.com/article.naver?doc_id=560008991'
res = urllib.request.urlopen(url)
print(res.status)
url = 'https://academic.naver.com/article.naver?doc_id=597939085'
res = urllib.request.urlopen(url)
print(res.status)
url = 'https://academic.naver.com/article.naver?doc_id=560008955'
res = urllib.request.urlopen(url)
print(res.status)
url = 'https://academic.naver.com/article.naver?doc_id=597939063'
res = urllib.request.urlopen(url)
print(res.status)
url = 'https://academic.naver.com/article.naver?doc_id=597939033'
res = urllib.request.urlopen(url)
print(res.status)
url = 'https://academic.naver.com/article.naver?doc_id=597938952'
res = urllib.request.urlopen(url)
print(res.status)
url = 'https://academic.naver.com/article.naver?doc_id=597938986'
res = urllib.request.urlopen(url)
print(res.status)
url = 'https://academic.naver.com/article.naver?doc_id=597939048'
res = urllib.request.urlopen(url)
print(res.status)
url = 'https://academic.naver.com/article.naver?doc_id=597939015'
res = urllib.request.urlopen(url)
print(res.status)
url = 'https://academic.naver.com/article.naver?doc_id=597938998'
res = urllib.request.urlopen(url)
print(res.status)
url = 'https://academic.naver.com/article.naver?doc_id=560008985'
res = urllib.request.urlopen(url)
print(res.status)
url = 'https://academic.naver.com/article.naver?doc_id=597938979'
res = urllib.request.urlopen(url)
print(res.status)
url = 'https://academic.naver.com/article.naver?doc_id=560008975'
res = urllib.request.urlopen(url)
print(res.status)
url = 'https://academic.naver.com/article.naver?doc_id=597939061'
res = urllib.request.urlopen(url)
print(res.status)
url = 'https://academic.naver.com/article.naver?doc_id=560008958'
res = urllib.request.urlopen(url)
print(res.status)
url = 'https://academic.naver.com/article.naver?doc_id=597939089'
res = urllib.request.urlopen(url)
print(res.status)
url = 'https://academic.naver.com/article.naver?doc_id=597938960'
res = urllib.request.urlopen(url)
print(res.status)
url = 'https://academic.naver.com/article.naver?doc_id=597938953'
res = urllib.request.urlopen(url)
print(res.status)
url = 'https://academic.naver.com/article.naver?doc_id=597939034'
res = urllib.request.urlopen(url)
print(res.status)
url = 'https://academic.naver.com/article.naver?doc_id=597938953'
res = urllib.request.urlopen(url)
print(res.status)
url = 'https://academic.naver.com/article.naver?doc_id=560009003'
res = urllib.request.urlopen(url)
print(res.status)
url = 'https://academic.naver.com/article.naver?doc_id=597939010'
res = urllib.request.urlopen(url)
print(res.status)
url = 'https://academic.naver.com/article.naver?doc_id=597938949'
res = urllib.request.urlopen(url)
print(res.status)
url = 'https://academic.naver.com/article.naver?doc_id=560008978'
res = urllib.request.urlopen(url)
print(res.status)
url = 'https://academic.naver.com/article.naver?doc_id=597939027'
res = urllib.request.urlopen(url)
print(res.status)
url = 'https://academic.naver.com/article.naver?doc_id=597939027'
res = urllib.request.urlopen(url)
print(res.status)
url = 'https://academic.naver.com/article.naver?doc_id=597939002'
res = urllib.request.urlopen(url)
print(res.status)
url = 'https://academic.naver.com/article.naver?doc_id=597939068'
res = urllib.request.urlopen(url)
print(res.status)
url = 'https://academic.naver.com/article.naver?doc_id=560008987'
res = urllib.request.urlopen(url)
print(res.status)
url = 'https://academic.naver.com/article.naver?doc_id=597939074'
res = urllib.request.urlopen(url)
print(res.status)
url = 'https://academic.naver.com/article.naver?doc_id=597939050'
res = urllib.request.urlopen(url)
print(res.status)
url = 'https://academic.naver.com/article.naver?doc_id=560008991'
res = urllib.request.urlopen(url)
print(res.status)
url = 'https://academic.naver.com/article.naver?doc_id=597939085'
res = urllib.request.urlopen(url)
print(res.status)
url = 'https://academic.naver.com/article.naver?doc_id=560008955'
res = urllib.request.urlopen(url)
print(res.status)
url = 'https://academic.naver.com/article.naver?doc_id=597939063'
res = urllib.request.urlopen(url)
print(res.status)
url = 'https://academic.naver.com/article.naver?doc_id=597939033'
res = urllib.request.urlopen(url)
print(res.status)
url = 'https://academic.naver.com/article.naver?doc_id=597938952'
res = urllib.request.urlopen(url)
print(res.status)
url = 'https://academic.naver.com/article.naver?doc_id=597938986'
res = urllib.request.urlopen(url)
print(res.status)
url = 'https://academic.naver.com/article.naver?doc_id=597939048'
res = urllib.request.urlopen(url)
print(res.status)
url = 'https://academic.naver.com/article.naver?doc_id=597939015'
res = urllib.request.urlopen(url)
print(res.status)
url = 'https://academic.naver.com/article.naver?doc_id=597938998'
res = urllib.request.urlopen(url)
print(res.status)
url = 'https://academic.naver.com/article.naver?doc_id=560008985'
res = urllib.request.urlopen(url)
print(res.status)
url = 'https://academic.naver.com/article.naver?doc_id=597938979'
res = urllib.request.urlopen(url)
print(res.status)
url = 'https://academic.naver.com/article.naver?doc_id=560008975'
res = urllib.request.urlopen(url)
print(res.status)
url = 'https://academic.naver.com/article.naver?doc_id=597939061'
res = urllib.request.urlopen(url)
print(res.status)
url = 'https://academic.naver.com/article.naver?doc_id=560008958'
res = urllib.request.urlopen(url)
print(res.status)
url = 'https://academic.naver.com/article.naver?doc_id=597939089'
res = urllib.request.urlopen(url)
print(res.status)
url = 'https://academic.naver.com/article.naver?doc_id=597938960'
res = urllib.request.urlopen(url)
print(res.status)
url = 'https://academic.naver.com/article.naver?doc_id=597938953'
res = urllib.request.urlopen(url)
print(res.status)
url = 'https://academic.naver.com/article.naver?doc_id=597939034'
res = urllib.request.urlopen(url)
print(res.status)
url = 'https://academic.naver.com/article.naver?doc_id=597938953'
res = urllib.request.urlopen(url)
print(res.status)
url = 'https://academic.naver.com/article.naver?doc_id=560009003'
res = urllib.request.urlopen(url)
print(res.status)
url = 'https://academic.naver.com/article.naver?doc_id=597939010'
res = urllib.request.urlopen(url)
print(res.status)
url = 'https://academic.naver.com/article.naver?doc_id=597938949'
res = urllib.request.urlopen(url)
print(res.status)
url = 'https://academic.naver.com/article.naver?doc_id=560008978'
res = urllib.request.urlopen(url)
print(res.status)
url = 'https://academic.naver.com/article.naver?doc_id=597939027'
res = urllib.request.urlopen(url)
print(res.status)
url = 'https://academic.naver.com/article.naver?doc_id=597939027'
res = urllib.request.urlopen(url)
print(res.status)
url = 'https://academic.naver.com/article.naver?doc_id=597939002'
res = urllib.request.urlopen(url)
print(res.status)
url = 'https://academic.naver.com/article.naver?doc_id=597939068'
res = urllib.request.urlopen(url)
print(res.status)
url = 'https://academic.naver.com/article.naver?doc_id=560008987'
res = urllib.request.urlopen(url)
print(res.status)
url = 'https://academic.naver.com/article.naver?doc_id=597939074'
res = urllib.request.urlopen(url)
print(res.status)
url = 'https://academic.naver.com/article.naver?doc_id=597939050'
res = urllib.request.urlopen(url)
print(res.status)
url = 'https://academic.naver.com/article.naver?doc_id=560008991'
res = urllib.request.urlopen(url)
print(res.status)
url = 'https://academic.naver.com/article.naver?doc_id=597939085'
res = urllib.request.urlopen(url)
print(res.status)
url = 'https://academic.naver.com/article.naver?doc_id=560008955'
res = urllib.request.urlopen(url)
print(res.status)
url = 'https://academic.naver.com/article.naver?doc_id=597939063'
res = urllib.request.urlopen(url)
print(res.status)
url = 'https://academic.naver.com/article.naver?doc_id=597939033'
res = urllib.request.urlopen(url)
print(res.status)
url = 'https://academic.naver.com/article.naver?doc_id=597938952'
res = urllib.request.urlopen(url)
print(res.status)
url = 'https://academic.naver.com/article.naver?doc_id=597938986'
res = urllib.request.urlopen(url)
print(res.status)
url = 'https://academic.naver.com/article.naver?doc_id=597939048'
res = urllib.request.urlopen(url)
print(res.status)
url = 'https://academic.naver.com/article.naver?doc_id=597939015'
res = urllib.request.urlopen(url)
print(res.status)
url = 'https://academic.naver.com/article.naver?doc_id=597938998'
res = urllib.request.urlopen(url)
print(res.status)
url = 'https://academic.naver.com/article.naver?doc_id=560008985'
res = urllib.request.urlopen(url)
print(res.status)
url = 'https://academic.naver.com/article.naver?doc_id=597938979'
res = urllib.request.urlopen(url)
print(res.status)
url = 'https://academic.naver.com/article.naver?doc_id=560008975'
res = urllib.request.urlopen(url)
print(res.status)
url = 'https://academic.naver.com/article.naver?doc_id=597939061'
res = urllib.request.urlopen(url)
print(res.status)
url = 'https://academic.naver.com/article.naver?doc_id=560008958'
res = urllib.request.urlopen(url)
print(res.status)
url = 'https://academic.naver.com/article.naver?doc_id=597939089'
res = urllib.request.urlopen(url)
print(res.status)
url = 'https://academic.naver.com/article.naver?doc_id=597938960'
res = urllib.request.urlopen(url)
print(res.status)
url = 'https://academic.naver.com/article.naver?doc_id=597938953'
res = urllib.request.urlopen(url)
print(res.status)
url = 'https://academic.naver.com/article.naver?doc_id=597939034'
res = urllib.request.urlopen(url)
print(res.status)
url = 'https://academic.naver.com/article.naver?doc_id=597938953'
res = urllib.request.urlopen(url)
print(res.status)
url = 'https://academic.naver.com/article.naver?doc_id=560009003'
res = urllib.request.urlopen(url)
print(res.status)
url = 'https://academic.naver.com/article.naver?doc_id=597939010'
res = urllib.request.urlopen(url)
print(res.status)
url = 'https://academic.naver.com/article.naver?doc_id=597938949'
res = urllib.request.urlopen(url)
print(res.status)
url = 'https://academic.naver.com/article.naver?doc_id=560008978'
res = urllib.request.urlopen(url)
print(res.status)
url = 'https://academic.naver.com/article.naver?doc_id=597939027'
res = urllib.request.urlopen(url)
print(res.status)
url = 'https://academic.naver.com/article.naver?doc_id=597939027'
res = urllib.request.urlopen(url)
print(res.status)
url = 'https://academic.naver.com/article.naver?doc_id=597939002'
res = urllib.request.urlopen(url)
print(res.status)
url = 'https://academic.naver.com/article.naver?doc_id=597939068'
res = urllib.request.urlopen(url)
print(res.status)
url = 'https://academic.naver.com/article.naver?doc_id=560008987'
res = urllib.request.urlopen(url)
print(res.status)
url = 'https://academic.naver.com/article.naver?doc_id=597939074'
res = urllib.request.urlopen(url)
print(res.status)
url = 'https://academic.naver.com/article.naver?doc_id=597939050'
res = urllib.request.urlopen(url)
print(res.status)
url = 'https://academic.naver.com/article.naver?doc_id=560008991'
res = urllib.request.urlopen(url)
print(res.status)
url = 'https://academic.naver.com/article.naver?doc_id=597939085'
res = urllib.request.urlopen(url)
print(res.status)
url = 'https://academic.naver.com/article.naver?doc_id=560008955'
res = urllib.request.urlopen(url)
print(res.status)
url = 'https://academic.naver.com/article.naver?doc_id=597939063'
res = urllib.request.urlopen(url)
print(res.status)
url = 'https://academic.naver.com/article.naver?doc_id=597939033'
res = urllib.request.urlopen(url)
print(res.status)
url = 'https://academic.naver.com/article.naver?doc_id=597938952'
res = urllib.request.urlopen(url)
print(res.status)
url = 'https://academic.naver.com/article.naver?doc_id=597938986'
res = urllib.request.urlopen(url)
print(res.status)
url = 'https://academic.naver.com/article.naver?doc_id=597939048'
res = urllib.request.urlopen(url)
print(res.status)
url = 'https://academic.naver.com/article.naver?doc_id=597939015'
res = urllib.request.urlopen(url)
print(res.status)
url = 'https://academic.naver.com/article.naver?doc_id=597938998'
res = urllib.request.urlopen(url)
print(res.status)
url = 'https://academic.naver.com/article.naver?doc_id=560008985'
res = urllib.request.urlopen(url)
print(res.status)
url = 'https://academic.naver.com/article.naver?doc_id=597938979'
res = urllib.request.urlopen(url)
print(res.status)
url = 'https://academic.naver.com/article.naver?doc_id=560008975'
res = urllib.request.urlopen(url)
print(res.status)
url = 'https://academic.naver.com/article.naver?doc_id=597939061'
res = urllib.request.urlopen(url)
print(res.status)
url = 'https://academic.naver.com/article.naver?doc_id=560008958'
res = urllib.request.urlopen(url)
print(res.status)
url = 'https://academic.naver.com/article.naver?doc_id=597939089'
res = urllib.request.urlopen(url)
print(res.status)
url = 'https://academic.naver.com/article.naver?doc_id=597938960'
res = urllib.request.urlopen(url)
print(res.status)
url = 'https://academic.naver.com/article.naver?doc_id=597938953'
res = urllib.request.urlopen(url)
print(res.status)
url = 'https://academic.naver.com/article.naver?doc_id=597939034'
res = urllib.request.urlopen(url)
print(res.status)
url = 'https://academic.naver.com/article.naver?doc_id=597938953'
res = urllib.request.urlopen(url)
print(res.status)
url = 'https://academic.naver.com/article.naver?doc_id=560009003'
res = urllib.request.urlopen(url)
print(res.status)
url = 'https://academic.naver.com/article.naver?doc_id=597939010'
res = urllib.request.urlopen(url)
print(res.status)
url = 'https://academic.naver.com/article.naver?doc_id=597938949'
res = urllib.request.urlopen(url)
print(res.status)
url = 'https://academic.naver.com/article.naver?doc_id=560008978'
res = urllib.request.urlopen(url)
print(res.status)
url = 'https://academic.naver.com/article.naver?doc_id=597939027'
res = urllib.request.urlopen(url)
print(res.status)
url = 'https://academic.naver.com/article.naver?doc_id=597939027'
res = urllib.request.urlopen(url)
print(res.status)
url = 'https://academic.naver.com/article.naver?doc_id=597939002'
res = urllib.request.urlopen(url)
print(res.status)
url = 'https://academic.naver.com/article.naver?doc_id=597939068'
res = urllib.request.urlopen(url)
print(res.status)
url = 'https://academic.naver.com/article.naver?doc_id=560008987'
res = urllib.request.urlopen(url)
print(res.status)
url = 'https://academic.naver.com/article.naver?doc_id=597939074'
res = urllib.request.urlopen(url)
print(res.status)
url = 'https://academic.naver.com/article.naver?doc_id=597939050'
res = urllib.request.urlopen(url)
print(res.status)
url = 'https://academic.naver.com/article.naver?doc_id=560008991'
res = urllib.request.urlopen(url)
print(res.status)
url = 'https://academic.naver.com/article.naver?doc_id=597939085'
res = urllib.request.urlopen(url)
print(res.status)
url = 'https://academic.naver.com/article.naver?doc_id=560008955'
res = urllib.request.urlopen(url)
print(res.status)
url = 'https://academic.naver.com/article.naver?doc_id=597939063'
res = urllib.request.urlopen(url)
print(res.status)
url = 'https://academic.naver.com/article.naver?doc_id=597939033'
res = urllib.request.urlopen(url)
print(res.status)
url = 'https://academic.naver.com/article.naver?doc_id=597938952'
res = urllib.request.urlopen(url)
print(res.status)
url = 'https://academic.naver.com/article.naver?doc_id=597938986'
res = urllib.request.urlopen(url)
print(res.status)
url = 'https://academic.naver.com/article.naver?doc_id=597939048'
res = urllib.request.urlopen(url)
print(res.status)
url = 'https://academic.naver.com/article.naver?doc_id=597939015'
res = urllib.request.urlopen(url)
print(res.status)
url = 'https://academic.naver.com/article.naver?doc_id=597938998'
res = urllib.request.urlopen(url)
print(res.status)
url = 'https://academic.naver.com/article.naver?doc_id=560008985'
res = urllib.request.urlopen(url)
print(res.status)
url = 'https://academic.naver.com/article.naver?doc_id=597938979'
res = urllib.request.urlopen(url)
print(res.status)
url = 'https://academic.naver.com/article.naver?doc_id=560008975'
res = urllib.request.urlopen(url)
print(res.status)
url = 'https://academic.naver.com/article.naver?doc_id=597939061'
res = urllib.request.urlopen(url)
print(res.status)
url = 'https://academic.naver.com/article.naver?doc_id=560008958'
res = urllib.request.urlopen(url)
print(res.status)
url = 'https://academic.naver.com/article.naver?doc_id=597939089'
res = urllib.request.urlopen(url)
print(res.status)
url = 'https://academic.naver.com/article.naver?doc_id=597938960'
res = urllib.request.urlopen(url)
print(res.status)
url = 'https://academic.naver.com/article.naver?doc_id=597938953'
res = urllib.request.urlopen(url)
print(res.status)
url = 'https://academic.naver.com/article.naver?doc_id=597939034'
res = urllib.request.urlopen(url)
print(res.status)
url = 'https://academic.naver.com/article.naver?doc_id=597938953'
res = urllib.request.urlopen(url)
print(res.status)
url = 'https://academic.naver.com/article.naver?doc_id=560009003'
res = urllib.request.urlopen(url)
print(res.status)
url = 'https://academic.naver.com/article.naver?doc_id=597939010'
res = urllib.request.urlopen(url)
print(res.status)
url = 'https://academic.naver.com/article.naver?doc_id=597938949'
res = urllib.request.urlopen(url)
print(res.status)
url = 'https://academic.naver.com/article.naver?doc_id=560008978'
res = urllib.request.urlopen(url)
print(res.status)
url = 'https://academic.naver.com/article.naver?doc_id=597939027'
res = urllib.request.urlopen(url)
print(res.status)
url = 'https://academic.naver.com/article.naver?doc_id=597939027'
res = urllib.request.urlopen(url)
print(res.status)
url = 'https://academic.naver.com/article.naver?doc_id=597939002'
res = urllib.request.urlopen(url)
print(res.status)
url = 'https://academic.naver.com/article.naver?doc_id=597939068'
res = urllib.request.urlopen(url)
print(res.status)
url = 'https://academic.naver.com/article.naver?doc_id=560008987'
res = urllib.request.urlopen(url)
print(res.status)
url = 'https://academic.naver.com/article.naver?doc_id=597939074'
res = urllib.request.urlopen(url)
print(res.status)
url = 'https://academic.naver.com/article.naver?doc_id=597939050'
res = urllib.request.urlopen(url)
print(res.status)
url = 'https://academic.naver.com/article.naver?doc_id=560008991'
res = urllib.request.urlopen(url)
print(res.status)
url = 'https://academic.naver.com/article.naver?doc_id=597939085'
res = urllib.request.urlopen(url)
print(res.status)
url = 'https://academic.naver.com/article.naver?doc_id=560008955'
res = urllib.request.urlopen(url)
print(res.status)
url = 'https://academic.naver.com/article.naver?doc_id=597939063'
res = urllib.request.urlopen(url)
print(res.status)
url = 'https://academic.naver.com/article.naver?doc_id=597939033'
res = urllib.request.urlopen(url)
print(res.status)
url = 'https://academic.naver.com/article.naver?doc_id=597938952'
res = urllib.request.urlopen(url)
print(res.status)
url = 'https://academic.naver.com/article.naver?doc_id=597938986'
res = urllib.request.urlopen(url)
print(res.status)
url = 'https://academic.naver.com/article.naver?doc_id=597939048'
res = urllib.request.urlopen(url)
print(res.status)
url = 'https://academic.naver.com/article.naver?doc_id=597939015'
res = urllib.request.urlopen(url)
print(res.status)
url = 'https://academic.naver.com/article.naver?doc_id=597938998'
res = urllib.request.urlopen(url)
print(res.status)
url = 'https://academic.naver.com/article.naver?doc_id=560008985'
res = urllib.request.urlopen(url)
print(res.status)
url = 'https://academic.naver.com/article.naver?doc_id=597938979'
res = urllib.request.urlopen(url)
print(res.status)
url = 'https://academic.naver.com/article.naver?doc_id=560008975'
res = urllib.request.urlopen(url)
print(res.status)
url = 'https://academic.naver.com/article.naver?doc_id=597939061'
res = urllib.request.urlopen(url)
print(res.status)
url = 'https://academic.naver.com/article.naver?doc_id=560008958'
res = urllib.request.urlopen(url)
print(res.status)
url = 'https://academic.naver.com/article.naver?doc_id=597939089'
res = urllib.request.urlopen(url)
print(res.status)
url = 'https://academic.naver.com/article.naver?doc_id=597938960'
res = urllib.request.urlopen(url)
print(res.status)
url = 'https://academic.naver.com/article.naver?doc_id=597938953'
res = urllib.request.urlopen(url)
print(res.status)
url = 'https://academic.naver.com/article.naver?doc_id=597939034'
res = urllib.request.urlopen(url)
print(res.status)
url = 'https://academic.naver.com/article.naver?doc_id=597938953'
res = urllib.request.urlopen(url)
print(res.status)
url = 'https://academic.naver.com/article.naver?doc_id=560009003'
res = urllib.request.urlopen(url)
print(res.status)
url = 'https://academic.naver.com/article.naver?doc_id=597939010'
res = urllib.request.urlopen(url)
print(res.status)
url = 'https://academic.naver.com/article.naver?doc_id=597938949'
res = urllib.request.urlopen(url)
print(res.status)
url = 'https://academic.naver.com/article.naver?doc_id=560008978'
res = urllib.request.urlopen(url)
print(res.status)
url = 'https://academic.naver.com/article.naver?doc_id=597939027'
res = urllib.request.urlopen(url)
print(res.status)
url = 'https://academic.naver.com/article.naver?doc_id=597939027'
res = urllib.request.urlopen(url)
print(res.status)
url = 'https://academic.naver.com/article.naver?doc_id=597939002'
res = urllib.request.urlopen(url)
print(res.status)
url = 'https://academic.naver.com/article.naver?doc_id=597939068'
res = urllib.request.urlopen(url)
print(res.status)
url = 'https://academic.naver.com/article.naver?doc_id=560008987'
res = urllib.request.urlopen(url)
print(res.status)
url = 'https://academic.naver.com/article.naver?doc_id=597939074'
res = urllib.request.urlopen(url)
print(res.status)
url = 'https://academic.naver.com/article.naver?doc_id=597939050'
res = urllib.request.urlopen(url)
print(res.status)
url = 'https://academic.naver.com/article.naver?doc_id=560008991'
res = urllib.request.urlopen(url)
print(res.status)
url = 'https://academic.naver.com/article.naver?doc_id=597939085'
res = urllib.request.urlopen(url)
print(res.status)
url = 'https://academic.naver.com/article.naver?doc_id=560008955'
res = urllib.request.urlopen(url)
print(res.status)
url = 'https://academic.naver.com/article.naver?doc_id=597939063'
res = urllib.request.urlopen(url)
print(res.status)
url = 'https://academic.naver.com/article.naver?doc_id=597939033'
res = urllib.request.urlopen(url)
print(res.status)
url = 'https://academic.naver.com/article.naver?doc_id=597938952'
res = urllib.request.urlopen(url)
print(res.status)
url = 'https://academic.naver.com/article.naver?doc_id=597938986'
res = urllib.request.urlopen(url)
print(res.status)
url = 'https://academic.naver.com/article.naver?doc_id=597939048'
res = urllib.request.urlopen(url)
print(res.status)
url = 'https://academic.naver.com/article.naver?doc_id=597939015'
res = urllib.request.urlopen(url)
print(res.status)
url = 'https://academic.naver.com/article.naver?doc_id=597938998'
res = urllib.request.urlopen(url)
print(res.status)
url = 'https://academic.naver.com/article.naver?doc_id=560008985'
res = urllib.request.urlopen(url)
print(res.status)
url = 'https://academic.naver.com/article.naver?doc_id=597938979'
res = urllib.request.urlopen(url)
print(res.status)
url = 'https://academic.naver.com/article.naver?doc_id=560008975'
res = urllib.request.urlopen(url)
print(res.status)
url = 'https://academic.naver.com/article.naver?doc_id=597939061'
res = urllib.request.urlopen(url)
print(res.status)
url = 'https://academic.naver.com/article.naver?doc_id=560008958'
res = urllib.request.urlopen(url)
print(res.status)
url = 'https://academic.naver.com/article.naver?doc_id=597939089'
res = urllib.request.urlopen(url)
print(res.status)
url = 'https://academic.naver.com/article.naver?doc_id=597938960'
res = urllib.request.urlopen(url)
print(res.status)
url = 'https://academic.naver.com/article.naver?doc_id=597938953'
res = urllib.request.urlopen(url)
print(res.status)
url = 'https://academic.naver.com/article.naver?doc_id=597939034'
res = urllib.request.urlopen(url)
print(res.status)
url = 'https://academic.naver.com/article.naver?doc_id=597938953'
res = urllib.request.urlopen(url)
print(res.status)
url = 'https://academic.naver.com/article.naver?doc_id=560009003'
res = urllib.request.urlopen(url)
print(res.status)
url = 'https://academic.naver.com/article.naver?doc_id=597939010'
res = urllib.request.urlopen(url)
print(res.status)
url = 'https://academic.naver.com/article.naver?doc_id=597938949'
res = urllib.request.urlopen(url)
print(res.status)
url = 'https://academic.naver.com/article.naver?doc_id=560008978'
res = urllib.request.urlopen(url)
print(res.status)
url = 'https://academic.naver.com/article.naver?doc_id=597939027'
res = urllib.request.urlopen(url)
print(res.status)
url = 'https://academic.naver.com/article.naver?doc_id=597939027'
res = urllib.request.urlopen(url)
print(res.status)
url = 'https://academic.naver.com/article.naver?doc_id=597939002'
res = urllib.request.urlopen(url)
print(res.status)
url = 'https://academic.naver.com/article.naver?doc_id=597939068'
res = urllib.request.urlopen(url)
print(res.status)
url = 'https://academic.naver.com/article.naver?doc_id=560008987'
res = urllib.request.urlopen(url)
print(res.status)
url = 'https://academic.naver.com/article.naver?doc_id=597939074'
res = urllib.request.urlopen(url)
print(res.status)
url = 'https://academic.naver.com/article.naver?doc_id=597939050'
res = urllib.request.urlopen(url)
print(res.status)
url = 'https://academic.naver.com/article.naver?doc_id=560008991'
res = urllib.request.urlopen(url)
print(res.status)
url = 'https://academic.naver.com/article.naver?doc_id=597939085'
res = urllib.request.urlopen(url)
print(res.status)
url = 'https://academic.naver.com/article.naver?doc_id=560008955'
res = urllib.request.urlopen(url)
print(res.status)
url = 'https://academic.naver.com/article.naver?doc_id=597939063'
res = urllib.request.urlopen(url)
print(res.status)
url = 'https://academic.naver.com/article.naver?doc_id=597939033'
res = urllib.request.urlopen(url)
print(res.status)
url = 'https://academic.naver.com/article.naver?doc_id=597938952'
res = urllib.request.urlopen(url)
print(res.status)
url = 'https://academic.naver.com/article.naver?doc_id=597938986'
res = urllib.request.urlopen(url)
print(res.status)
url = 'https://academic.naver.com/article.naver?doc_id=597939048'
res = urllib.request.urlopen(url)
print(res.status)
url = 'https://academic.naver.com/article.naver?doc_id=597939015'
res = urllib.request.urlopen(url)
print(res.status)
url = 'https://academic.naver.com/article.naver?doc_id=597938998'
res = urllib.request.urlopen(url)
print(res.status)
url = 'https://academic.naver.com/article.naver?doc_id=560008985'
res = urllib.request.urlopen(url)
print(res.status)
url = 'https://academic.naver.com/article.naver?doc_id=597938979'
res = urllib.request.urlopen(url)
print(res.status)
url = 'https://academic.naver.com/article.naver?doc_id=560008975'
res = urllib.request.urlopen(url)
print(res.status)
url = 'https://academic.naver.com/article.naver?doc_id=597939061'
res = urllib.request.urlopen(url)
print(res.status)
url = 'https://academic.naver.com/article.naver?doc_id=560008958'
res = urllib.request.urlopen(url)
print(res.status)
url = 'https://academic.naver.com/article.naver?doc_id=597939089'
res = urllib.request.urlopen(url)
print(res.status)
url = 'https://academic.naver.com/article.naver?doc_id=597938960'
res = urllib.request.urlopen(url)
print(res.status)
url = 'https://academic.naver.com/article.naver?doc_id=597938953'
res = urllib.request.urlopen(url)
print(res.status)
url = 'https://academic.naver.com/article.naver?doc_id=597939034'
res = urllib.request.urlopen(url)
print(res.status)
url = 'https://academic.naver.com/article.naver?doc_id=597938953'
res = urllib.request.urlopen(url)
print(res.status)
url = 'https://academic.naver.com/article.naver?doc_id=560009003'
res = urllib.request.urlopen(url)
print(res.status)
url = 'https://academic.naver.com/article.naver?doc_id=597939010'
res = urllib.request.urlopen(url)
print(res.status)
url = 'https://academic.naver.com/article.naver?doc_id=597938949'
res = urllib.request.urlopen(url)
print(res.status)
url = 'https://academic.naver.com/article.naver?doc_id=560008978'
res = urllib.request.urlopen(url)
print(res.status)
url = 'https://academic.naver.com/article.naver?doc_id=597939027'
res = urllib.request.urlopen(url)
print(res.status)
url = 'https://academic.naver.com/article.naver?doc_id=597939027'
res = urllib.request.urlopen(url)
print(res.status)
url = 'https://academic.naver.com/article.naver?doc_id=597939002'
res = urllib.request.urlopen(url)
print(res.status)
url = 'https://academic.naver.com/article.naver?doc_id=597939068'
res = urllib.request.urlopen(url)
print(res.status)
url = 'https://academic.naver.com/article.naver?doc_id=560008987'
res = urllib.request.urlopen(url)
print(res.status)
url = 'https://academic.naver.com/article.naver?doc_id=597939074'
res = urllib.request.urlopen(url)
print(res.status)
url = 'https://academic.naver.com/article.naver?doc_id=597939050'
res = urllib.request.urlopen(url)
print(res.status)
url = 'https://academic.naver.com/article.naver?doc_id=560008991'
res = urllib.request.urlopen(url)
print(res.status)
url = 'https://academic.naver.com/article.naver?doc_id=597939085'
res = urllib.request.urlopen(url)
print(res.status)
url = 'https://academic.naver.com/article.naver?doc_id=560008955'
res = urllib.request.urlopen(url)
print(res.status)
url = 'https://academic.naver.com/article.naver?doc_id=597939063'
res = urllib.request.urlopen(url)
print(res.status)
url = 'https://academic.naver.com/article.naver?doc_id=597939033'
res = urllib.request.urlopen(url)
print(res.status)
url = 'https://academic.naver.com/article.naver?doc_id=597938952'
res = urllib.request.urlopen(url)
print(res.status)
url = 'https://academic.naver.com/article.naver?doc_id=597938986'
res = urllib.request.urlopen(url)
print(res.status)
url = 'https://academic.naver.com/article.naver?doc_id=597939048'
res = urllib.request.urlopen(url)
print(res.status)
url = 'https://academic.naver.com/article.naver?doc_id=597939015'
res = urllib.request.urlopen(url)
print(res.status)
url = 'https://academic.naver.com/article.naver?doc_id=597938998'
res = urllib.request.urlopen(url)
print(res.status)
url = 'https://academic.naver.com/article.naver?doc_id=560008985'
res = urllib.request.urlopen(url)
print(res.status)
url = 'https://academic.naver.com/article.naver?doc_id=597938979'
res = urllib.request.urlopen(url)
print(res.status)
url = 'https://academic.naver.com/article.naver?doc_id=560008975'
res = urllib.request.urlopen(url)
print(res.status)
url = 'https://academic.naver.com/article.naver?doc_id=597939061'
res = urllib.request.urlopen(url)
print(res.status)
url = 'https://academic.naver.com/article.naver?doc_id=560008958'
res = urllib.request.urlopen(url)
print(res.status)
url = 'https://academic.naver.com/article.naver?doc_id=597939089'
res = urllib.request.urlopen(url)
print(res.status)
url = 'https://academic.naver.com/article.naver?doc_id=597938960'
res = urllib.request.urlopen(url)
print(res.status)
url = 'https://academic.naver.com/article.naver?doc_id=597938953'
res = urllib.request.urlopen(url)
print(res.status)
url = 'https://academic.naver.com/article.naver?doc_id=597939034'
res = urllib.request.urlopen(url)
print(res.status)
url = 'https://academic.naver.com/article.naver?doc_id=597938953'
res = urllib.request.urlopen(url)
print(res.status)
url = 'https://academic.naver.com/article.naver?doc_id=560009003'
res = urllib.request.urlopen(url)
print(res.status)
url = 'https://academic.naver.com/article.naver?doc_id=597939010'
res = urllib.request.urlopen(url)
print(res.status)
url = 'https://academic.naver.com/article.naver?doc_id=597938949'
res = urllib.request.urlopen(url)
print(res.status)
url = 'https://academic.naver.com/article.naver?doc_id=560008978'
res = urllib.request.urlopen(url)
print(res.status)
url = 'https://academic.naver.com/article.naver?doc_id=597939027'
res = urllib.request.urlopen(url)
print(res.status)
url = 'https://academic.naver.com/article.naver?doc_id=597939027'
res = urllib.request.urlopen(url)
print(res.status)
url = 'https://academic.naver.com/article.naver?doc_id=597939002'
res = urllib.request.urlopen(url)
print(res.status)
url = 'https://academic.naver.com/article.naver?doc_id=597939068'
res = urllib.request.urlopen(url)
print(res.status)
url = 'https://academic.naver.com/article.naver?doc_id=560008987'
res = urllib.request.urlopen(url)
print(res.status)
url = 'https://academic.naver.com/article.naver?doc_id=597939074'
res = urllib.request.urlopen(url)
print(res.status)
url = 'https://academic.naver.com/article.naver?doc_id=597939050'
res = urllib.request.urlopen(url)
print(res.status)
url = 'https://academic.naver.com/article.naver?doc_id=560008991'
res = urllib.request.urlopen(url)
print(res.status)
url = 'https://academic.naver.com/article.naver?doc_id=597939085'
res = urllib.request.urlopen(url)
print(res.status)
url = 'https://academic.naver.com/article.naver?doc_id=560008955'
res = urllib.request.urlopen(url)
print(res.status)
url = 'https://academic.naver.com/article.naver?doc_id=597939063'
res = urllib.request.urlopen(url)
print(res.status)
url = 'https://academic.naver.com/article.naver?doc_id=597939033'
res = urllib.request.urlopen(url)
print(res.status)
url = 'https://academic.naver.com/article.naver?doc_id=597938952'
res = urllib.request.urlopen(url)
print(res.status)
url = 'https://academic.naver.com/article.naver?doc_id=597938986'
res = urllib.request.urlopen(url)
print(res.status)
url = 'https://academic.naver.com/article.naver?doc_id=597939048'
res = urllib.request.urlopen(url)
print(res.status)
url = 'https://academic.naver.com/article.naver?doc_id=597939015'
res = urllib.request.urlopen(url)
print(res.status)
url = 'https://academic.naver.com/article.naver?doc_id=597938998'
res = urllib.request.urlopen(url)
print(res.status)
url = 'https://academic.naver.com/article.naver?doc_id=560008985'
res = urllib.request.urlopen(url)
print(res.status)
url = 'https://academic.naver.com/article.naver?doc_id=597938979'
res = urllib.request.urlopen(url)
print(res.status)
url = 'https://academic.naver.com/article.naver?doc_id=560008975'
res = urllib.request.urlopen(url)
print(res.status)
url = 'https://academic.naver.com/article.naver?doc_id=597939061'
res = urllib.request.urlopen(url)
print(res.status)
url = 'https://academic.naver.com/article.naver?doc_id=560008958'
res = urllib.request.urlopen(url)
print(res.status)
url = 'https://academic.naver.com/article.naver?doc_id=597939089'
res = urllib.request.urlopen(url)
print(res.status)
url = 'https://academic.naver.com/article.naver?doc_id=597938960'
res = urllib.request.urlopen(url)
print(res.status)
url = 'https://academic.naver.com/article.naver?doc_id=597938953'
res = urllib.request.urlopen(url)
print(res.status)
url = 'https://academic.naver.com/article.naver?doc_id=597939034'
res = urllib.request.urlopen(url)
print(res.status)
url = 'https://academic.naver.com/article.naver?doc_id=597938953'
res = urllib.request.urlopen(url)
print(res.status)
url = 'https://academic.naver.com/article.naver?doc_id=560009003'
res = urllib.request.urlopen(url)
print(res.status)
url = 'https://academic.naver.com/article.naver?doc_id=597939010'
res = urllib.request.urlopen(url)
print(res.status)
url = 'https://academic.naver.com/article.naver?doc_id=597938949'
res = urllib.request.urlopen(url)
print(res.status)
url = 'https://academic.naver.com/article.naver?doc_id=560008978'
res = urllib.request.urlopen(url)
print(res.status)
url = 'https://academic.naver.com/article.naver?doc_id=597939027'
res = urllib.request.urlopen(url)
print(res.status)
url = 'https://academic.naver.com/article.naver?doc_id=597939027'
res = urllib.request.urlopen(url)
print(res.status)
url = 'https://academic.naver.com/article.naver?doc_id=597939002'
res = urllib.request.urlopen(url)
print(res.status)
url = 'https://academic.naver.com/article.naver?doc_id=597939068'
res = urllib.request.urlopen(url)
print(res.status)
url = 'https://academic.naver.com/article.naver?doc_id=560008987'
res = urllib.request.urlopen(url)
print(res.status)
url = 'https://academic.naver.com/article.naver?doc_id=597939074'
res = urllib.request.urlopen(url)
print(res.status)
url = 'https://academic.naver.com/article.naver?doc_id=597939050'
res = urllib.request.urlopen(url)
print(res.status)
url = 'https://academic.naver.com/article.naver?doc_id=560008991'
res = urllib.request.urlopen(url)
print(res.status)
url = 'https://academic.naver.com/article.naver?doc_id=597939085'
res = urllib.request.urlopen(url)
print(res.status)
url = 'https://academic.naver.com/article.naver?doc_id=560008955'
res = urllib.request.urlopen(url)
print(res.status)
url = 'https://academic.naver.com/article.naver?doc_id=597939063'
res = urllib.request.urlopen(url)
print(res.status)
url = 'https://academic.naver.com/article.naver?doc_id=597939033'
res = urllib.request.urlopen(url)
print(res.status)
url = 'https://academic.naver.com/article.naver?doc_id=597938952'
res = urllib.request.urlopen(url)
print(res.status)
url = 'https://academic.naver.com/article.naver?doc_id=597938986'
res = urllib.request.urlopen(url)
print(res.status)
url = 'https://academic.naver.com/article.naver?doc_id=597939048'
res = urllib.request.urlopen(url)
print(res.status)
url = 'https://academic.naver.com/article.naver?doc_id=597939015'
res = urllib.request.urlopen(url)
print(res.status)
url = 'https://academic.naver.com/article.naver?doc_id=597938998'
res = urllib.request.urlopen(url)
print(res.status)
url = 'https://academic.naver.com/article.naver?doc_id=560008985'
res = urllib.request.urlopen(url)
print(res.status)
url = 'https://academic.naver.com/article.naver?doc_id=597938979'
res = urllib.request.urlopen(url)
print(res.status)
url = 'https://academic.naver.com/article.naver?doc_id=560008975'
res = urllib.request.urlopen(url)
print(res.status)
url = 'https://academic.naver.com/article.naver?doc_id=597939061'
res = urllib.request.urlopen(url)
print(res.status)
url = 'https://academic.naver.com/article.naver?doc_id=560008958'
res = urllib.request.urlopen(url)
print(res.status)
url = 'https://academic.naver.com/article.naver?doc_id=597939089'
res = urllib.request.urlopen(url)
print(res.status)
url = 'https://academic.naver.com/article.naver?doc_id=597938960'
res = urllib.request.urlopen(url)
print(res.status)
url = 'https://academic.naver.com/article.naver?doc_id=597938953'
res = urllib.request.urlopen(url)
print(res.status)
url = 'https://academic.naver.com/article.naver?doc_id=597939034'
res = urllib.request.urlopen(url)
print(res.status)
url = 'https://academic.naver.com/article.naver?doc_id=597938953'
res = urllib.request.urlopen(url)
print(res.status)
url = 'https://academic.naver.com/article.naver?doc_id=560009003'
res = urllib.request.urlopen(url)
print(res.status)
url = 'https://academic.naver.com/article.naver?doc_id=597939010'
res = urllib.request.urlopen(url)
print(res.status)
url = 'https://academic.naver.com/article.naver?doc_id=597938949'
res = urllib.request.urlopen(url)
print(res.status)
url = 'https://academic.naver.com/article.naver?doc_id=560008978'
res = urllib.request.urlopen(url)
print(res.status)
url = 'https://academic.naver.com/article.naver?doc_id=597939027'
res = urllib.request.urlopen(url)
print(res.status)
url = 'https://academic.naver.com/article.naver?doc_id=597939027'
res = urllib.request.urlopen(url)
print(res.status)
url = 'https://academic.naver.com/article.naver?doc_id=597939002'
res = urllib.request.urlopen(url)
print(res.status)
url = 'https://academic.naver.com/article.naver?doc_id=597939068'
res = urllib.request.urlopen(url)
print(res.status)
url = 'https://academic.naver.com/article.naver?doc_id=560008987'
res = urllib.request.urlopen(url)
print(res.status)
url = 'https://academic.naver.com/article.naver?doc_id=597939074'
res = urllib.request.urlopen(url)
print(res.status)
url = 'https://academic.naver.com/article.naver?doc_id=597939050'
res = urllib.request.urlopen(url)
print(res.status)
url = 'https://academic.naver.com/article.naver?doc_id=560008991'
res = urllib.request.urlopen(url)
print(res.status)
url = 'https://academic.naver.com/article.naver?doc_id=597939085'
res = urllib.request.urlopen(url)
print(res.status)
url = 'https://academic.naver.com/article.naver?doc_id=560008955'
res = urllib.request.urlopen(url)
print(res.status)
url = 'https://academic.naver.com/article.naver?doc_id=597939063'
res = urllib.request.urlopen(url)
print(res.status)
url = 'https://academic.naver.com/article.naver?doc_id=597939033'
res = urllib.request.urlopen(url)
print(res.status)
url = 'https://academic.naver.com/article.naver?doc_id=597938952'
res = urllib.request.urlopen(url)
print(res.status)
url = 'https://academic.naver.com/article.naver?doc_id=597938986'
res = urllib.request.urlopen(url)
print(res.status)
url = 'https://academic.naver.com/article.naver?doc_id=597939048'
res = urllib.request.urlopen(url)
print(res.status)
url = 'https://academic.naver.com/article.naver?doc_id=597939015'
res = urllib.request.urlopen(url)
print(res.status)
url = 'https://academic.naver.com/article.naver?doc_id=597938998'
res = urllib.request.urlopen(url)
print(res.status)
url = 'https://academic.naver.com/article.naver?doc_id=560008985'
res = urllib.request.urlopen(url)
print(res.status)
url = 'https://academic.naver.com/article.naver?doc_id=597938979'
res = urllib.request.urlopen(url)
print(res.status)
url = 'https://academic.naver.com/article.naver?doc_id=560008975'
res = urllib.request.urlopen(url)
print(res.status)
url = 'https://academic.naver.com/article.naver?doc_id=597939061'
res = urllib.request.urlopen(url)
print(res.status)
url = 'https://academic.naver.com/article.naver?doc_id=560008958'
res = urllib.request.urlopen(url)
print(res.status)
url = 'https://academic.naver.com/article.naver?doc_id=597939089'
res = urllib.request.urlopen(url)
print(res.status)
url = 'https://academic.naver.com/article.naver?doc_id=597938960'
res = urllib.request.urlopen(url)
print(res.status)
url = 'https://academic.naver.com/article.naver?doc_id=597938953'
res = urllib.request.urlopen(url)
print(res.status)
url = 'https://academic.naver.com/article.naver?doc_id=597939034'
res = urllib.request.urlopen(url)
print(res.status)
url = 'https://academic.naver.com/article.naver?doc_id=597938953'
res = urllib.request.urlopen(url)
print(res.status)
url = 'https://academic.naver.com/article.naver?doc_id=560009003'
res = urllib.request.urlopen(url)
print(res.status)
url = 'https://academic.naver.com/article.naver?doc_id=597939010'
res = urllib.request.urlopen(url)
print(res.status)
url = 'https://academic.naver.com/article.naver?doc_id=597938949'
res = urllib.request.urlopen(url)
print(res.status)
url = 'https://academic.naver.com/article.naver?doc_id=560008978'
res = urllib.request.urlopen(url)
print(res.status)
url = 'https://academic.naver.com/article.naver?doc_id=597939027'
res = urllib.request.urlopen(url)
print(res.status)
url = 'https://academic.naver.com/article.naver?doc_id=597939027'
res = urllib.request.urlopen(url)
print(res.status)
url = 'https://academic.naver.com/article.naver?doc_id=597939002'
res = urllib.request.urlopen(url)
print(res.status)
url = 'https://academic.naver.com/article.naver?doc_id=597939068'
res = urllib.request.urlopen(url)
print(res.status)
url = 'https://academic.naver.com/article.naver?doc_id=560008987'
res = urllib.request.urlopen(url)
print(res.status)
url = 'https://academic.naver.com/article.naver?doc_id=597939074'
res = urllib.request.urlopen(url)
print(res.status)
url = 'https://academic.naver.com/article.naver?doc_id=597939050'
res = urllib.request.urlopen(url)
print(res.status)
url = 'https://academic.naver.com/article.naver?doc_id=560008991'
res = urllib.request.urlopen(url)
print(res.status)
url = 'https://academic.naver.com/article.naver?doc_id=597939085'
res = urllib.request.urlopen(url)
print(res.status)
url = 'https://academic.naver.com/article.naver?doc_id=560008955'
res = urllib.request.urlopen(url)
print(res.status)
url = 'https://academic.naver.com/article.naver?doc_id=597939063'
res = urllib.request.urlopen(url)
print(res.status)
url = 'https://academic.naver.com/article.naver?doc_id=597939033'
res = urllib.request.urlopen(url)
print(res.status)
url = 'https://academic.naver.com/article.naver?doc_id=597938952'
res = urllib.request.urlopen(url)
print(res.status)
url = 'https://academic.naver.com/article.naver?doc_id=597938986'
res = urllib.request.urlopen(url)
print(res.status)
url = 'https://academic.naver.com/article.naver?doc_id=597939048'
res = urllib.request.urlopen(url)
print(res.status)
url = 'https://academic.naver.com/article.naver?doc_id=597939015'
res = urllib.request.urlopen(url)
print(res.status)
url = 'https://academic.naver.com/article.naver?doc_id=597938998'
res = urllib.request.urlopen(url)
print(res.status)
url = 'https://academic.naver.com/article.naver?doc_id=560008985'
res = urllib.request.urlopen(url)
print(res.status)
url = 'https://academic.naver.com/article.naver?doc_id=597938979'
res = urllib.request.urlopen(url)
print(res.status)
url = 'https://academic.naver.com/article.naver?doc_id=560008975'
res = urllib.request.urlopen(url)
print(res.status)
url = 'https://academic.naver.com/article.naver?doc_id=597939061'
res = urllib.request.urlopen(url)
print(res.status)
url = 'https://academic.naver.com/article.naver?doc_id=560008958'
res = urllib.request.urlopen(url)
print(res.status)
url = 'https://academic.naver.com/article.naver?doc_id=597939089'
res = urllib.request.urlopen(url)
print(res.status)
url = 'https://academic.naver.com/article.naver?doc_id=597938960'
res = urllib.request.urlopen(url)
print(res.status)
url = 'https://academic.naver.com/article.naver?doc_id=597938953'
res = urllib.request.urlopen(url)
print(res.status)
url = 'https://academic.naver.com/article.naver?doc_id=597939034'
res = urllib.request.urlopen(url)
print(res.status)
url = 'https://academic.naver.com/article.naver?doc_id=597938953'
res = urllib.request.urlopen(url)
print(res.status)
url = 'https://academic.naver.com/article.naver?doc_id=560009003'
res = urllib.request.urlopen(url)
print(res.status)
url = 'https://academic.naver.com/article.naver?doc_id=597939010'
res = urllib.request.urlopen(url)
print(res.status)
url = 'https://academic.naver.com/article.naver?doc_id=597938949'
res = urllib.request.urlopen(url)
print(res.status)
url = 'https://academic.naver.com/article.naver?doc_id=560008978'
res = urllib.request.urlopen(url)
print(res.status)
url = 'https://academic.naver.com/article.naver?doc_id=597939027'
res = urllib.request.urlopen(url)
print(res.status)
url = 'https://academic.naver.com/article.naver?doc_id=597939027'
res = urllib.request.urlopen(url)
print(res.status)
url = 'https://academic.naver.com/article.naver?doc_id=597939002'
res = urllib.request.urlopen(url)
print(res.status)
url = 'https://academic.naver.com/article.naver?doc_id=597939068'
res = urllib.request.urlopen(url)
print(res.status)
url = 'https://academic.naver.com/article.naver?doc_id=560008987'
res = urllib.request.urlopen(url)
print(res.status)
url = 'https://academic.naver.com/article.naver?doc_id=597939074'
res = urllib.request.urlopen(url)
print(res.status)
url = 'https://academic.naver.com/article.naver?doc_id=597939050'
res = urllib.request.urlopen(url)
print(res.status)
url = 'https://academic.naver.com/article.naver?doc_id=560008991'
res = urllib.request.urlopen(url)
print(res.status)
url = 'https://academic.naver.com/article.naver?doc_id=597939085'
res = urllib.request.urlopen(url)
print(res.status)
url = 'https://academic.naver.com/article.naver?doc_id=560008955'
res = urllib.request.urlopen(url)
print(res.status)
url = 'https://academic.naver.com/article.naver?doc_id=597939063'
res = urllib.request.urlopen(url)
print(res.status)
url = 'https://academic.naver.com/article.naver?doc_id=597939033'
res = urllib.request.urlopen(url)
print(res.status)
url = 'https://academic.naver.com/article.naver?doc_id=597938952'
res = urllib.request.urlopen(url)
print(res.status)
url = 'https://academic.naver.com/article.naver?doc_id=597938986'
res = urllib.request.urlopen(url)
print(res.status)
url = 'https://academic.naver.com/article.naver?doc_id=597939048'
res = urllib.request.urlopen(url)
print(res.status)
url = 'https://academic.naver.com/article.naver?doc_id=597939015'
res = urllib.request.urlopen(url)
print(res.status)
url = 'https://academic.naver.com/article.naver?doc_id=597938998'
res = urllib.request.urlopen(url)
print(res.status)
url = 'https://academic.naver.com/article.naver?doc_id=560008985'
res = urllib.request.urlopen(url)
print(res.status)
url = 'https://academic.naver.com/article.naver?doc_id=597938979'
res = urllib.request.urlopen(url)
print(res.status)
url = 'https://academic.naver.com/article.naver?doc_id=560008975'
res = urllib.request.urlopen(url)
print(res.status)
url = 'https://academic.naver.com/article.naver?doc_id=597939061'
res = urllib.request.urlopen(url)
print(res.status)
url = 'https://academic.naver.com/article.naver?doc_id=560008958'
res = urllib.request.urlopen(url)
print(res.status)
url = 'https://academic.naver.com/article.naver?doc_id=597939089'
res = urllib.request.urlopen(url)
print(res.status)
url = 'https://academic.naver.com/article.naver?doc_id=597938960'
res = urllib.request.urlopen(url)
print(res.status)
url = 'https://academic.naver.com/article.naver?doc_id=597938953'
res = urllib.request.urlopen(url)
print(res.status)
url = 'https://academic.naver.com/article.naver?doc_id=597939034'
res = urllib.request.urlopen(url)
print(res.status)
url = 'https://academic.naver.com/article.naver?doc_id=597938953'
res = urllib.request.urlopen(url)
print(res.status)
url = 'https://academic.naver.com/article.naver?doc_id=560009003'
res = urllib.request.urlopen(url)
print(res.status)
url = 'https://academic.naver.com/article.naver?doc_id=597939010'
res = urllib.request.urlopen(url)
print(res.status)
url = 'https://academic.naver.com/article.naver?doc_id=597938949'
res = urllib.request.urlopen(url)
print(res.status)
url = 'https://academic.naver.com/article.naver?doc_id=560008978'
res = urllib.request.urlopen(url)
print(res.status)
url = 'https://academic.naver.com/article.naver?doc_id=597939027'
res = urllib.request.urlopen(url)
print(res.status)
url = 'https://academic.naver.com/article.naver?doc_id=597939027'
res = urllib.request.urlopen(url)
print(res.status)
url = 'https://academic.naver.com/article.naver?doc_id=597939002'
res = urllib.request.urlopen(url)
print(res.status)
url = 'https://academic.naver.com/article.naver?doc_id=597939068'
res = urllib.request.urlopen(url)
print(res.status)
url = 'https://academic.naver.com/article.naver?doc_id=560008987'
res = urllib.request.urlopen(url)
print(res.status)
url = 'https://academic.naver.com/article.naver?doc_id=597939074'
res = urllib.request.urlopen(url)
print(res.status)
url = 'https://academic.naver.com/article.naver?doc_id=597939050'
res = urllib.request.urlopen(url)
print(res.status)
url = 'https://academic.naver.com/article.naver?doc_id=560008991'
res = urllib.request.urlopen(url)
print(res.status)
url = 'https://academic.naver.com/article.naver?doc_id=597939085'
res = urllib.request.urlopen(url)
print(res.status)
url = 'https://academic.naver.com/article.naver?doc_id=560008955'
res = urllib.request.urlopen(url)
print(res.status)
url = 'https://academic.naver.com/article.naver?doc_id=597939063'
res = urllib.request.urlopen(url)
print(res.status)
url = 'https://academic.naver.com/article.naver?doc_id=597939033'
res = urllib.request.urlopen(url)
print(res.status)
url = 'https://academic.naver.com/article.naver?doc_id=597938952'
res = urllib.request.urlopen(url)
print(res.status)
url = 'https://academic.naver.com/article.naver?doc_id=597938986'
res = urllib.request.urlopen(url)
print(res.status)
url = 'https://academic.naver.com/article.naver?doc_id=597939048'
res = urllib.request.urlopen(url)
print(res.status)
url = 'https://academic.naver.com/article.naver?doc_id=597939015'
res = urllib.request.urlopen(url)
print(res.status)
url = 'https://academic.naver.com/article.naver?doc_id=597938998'
res = urllib.request.urlopen(url)
print(res.status)
url = 'https://academic.naver.com/article.naver?doc_id=560008985'
res = urllib.request.urlopen(url)
print(res.status)
url = 'https://academic.naver.com/article.naver?doc_id=597938979'
res = urllib.request.urlopen(url)
print(res.status)
url = 'https://academic.naver.com/article.naver?doc_id=560008975'
res = urllib.request.urlopen(url)
print(res.status)
url = 'https://academic.naver.com/article.naver?doc_id=597939061'
res = urllib.request.urlopen(url)
print(res.status)
url = 'https://academic.naver.com/article.naver?doc_id=560008958'
res = urllib.request.urlopen(url)
print(res.status)
url = 'https://academic.naver.com/article.naver?doc_id=597939089'
res = urllib.request.urlopen(url)
print(res.status)
url = 'https://academic.naver.com/article.naver?doc_id=597938960'
res = urllib.request.urlopen(url)
print(res.status)
url = 'https://academic.naver.com/article.naver?doc_id=597938953'
res = urllib.request.urlopen(url)
print(res.status)
url = 'https://academic.naver.com/article.naver?doc_id=597939034'
res = urllib.request.urlopen(url)
print(res.status)
url = 'https://academic.naver.com/article.naver?doc_id=597938953'
res = urllib.request.urlopen(url)
print(res.status)
url = 'https://academic.naver.com/article.naver?doc_id=560009003'
res = urllib.request.urlopen(url)
print(res.status)
url = 'https://academic.naver.com/article.naver?doc_id=597939010'
res = urllib.request.urlopen(url)
print(res.status)
url = 'https://academic.naver.com/article.naver?doc_id=597938949'
res = urllib.request.urlopen(url)
print(res.status)
url = 'https://academic.naver.com/article.naver?doc_id=560008978'
res = urllib.request.urlopen(url)
print(res.status)
url = 'https://academic.naver.com/article.naver?doc_id=597939027'
res = urllib.request.urlopen(url)
print(res.status)
url = 'https://academic.naver.com/article.naver?doc_id=597939027'
res = urllib.request.urlopen(url)
print(res.status)
url = 'https://academic.naver.com/article.naver?doc_id=597939002'
res = urllib.request.urlopen(url)
print(res.status)
url = 'https://academic.naver.com/article.naver?doc_id=597939068'
res = urllib.request.urlopen(url)
print(res.status)
url = 'https://academic.naver.com/article.naver?doc_id=560008987'
res = urllib.request.urlopen(url)
print(res.status)
url = 'https://academic.naver.com/article.naver?doc_id=597939074'
res = urllib.request.urlopen(url)
print(res.status)
url = 'https://academic.naver.com/article.naver?doc_id=597939050'
res = urllib.request.urlopen(url)
print(res.status)
url = 'https://academic.naver.com/article.naver?doc_id=560008991'
res = urllib.request.urlopen(url)
print(res.status)
url = 'https://academic.naver.com/article.naver?doc_id=597939085'
res = urllib.request.urlopen(url)
print(res.status)
url = 'https://academic.naver.com/article.naver?doc_id=560008955'
res = urllib.request.urlopen(url)
print(res.status)
url = 'https://academic.naver.com/article.naver?doc_id=597939063'
res = urllib.request.urlopen(url)
print(res.status)
url = 'https://academic.naver.com/article.naver?doc_id=597939033'
res = urllib.request.urlopen(url)
print(res.status)
url = 'https://academic.naver.com/article.naver?doc_id=597938952'
res = urllib.request.urlopen(url)
print(res.status)
url = 'https://academic.naver.com/article.naver?doc_id=597938986'
res = urllib.request.urlopen(url)
print(res.status)
url = 'https://academic.naver.com/article.naver?doc_id=597939048'
res = urllib.request.urlopen(url)
print(res.status)
url = 'https://academic.naver.com/article.naver?doc_id=597939015'
res = urllib.request.urlopen(url)
print(res.status)
url = 'https://academic.naver.com/article.naver?doc_id=597938998'
res = urllib.request.urlopen(url)
print(res.status)
url = 'https://academic.naver.com/article.naver?doc_id=560008985'
res = urllib.request.urlopen(url)
print(res.status)
url = 'https://academic.naver.com/article.naver?doc_id=597938979'
res = urllib.request.urlopen(url)
print(res.status)
url = 'https://academic.naver.com/article.naver?doc_id=560008975'
res = urllib.request.urlopen(url)
print(res.status)
url = 'https://academic.naver.com/article.naver?doc_id=597939061'
res = urllib.request.urlopen(url)
print(res.status)
url = 'https://academic.naver.com/article.naver?doc_id=560008958'
res = urllib.request.urlopen(url)
print(res.status)
url = 'https://academic.naver.com/article.naver?doc_id=597939089'
res = urllib.request.urlopen(url)
print(res.status)
url = 'https://academic.naver.com/article.naver?doc_id=597938960'
res = urllib.request.urlopen(url)
print(res.status)
url = 'https://academic.naver.com/article.naver?doc_id=597938953'
res = urllib.request.urlopen(url)
print(res.status)
url = 'https://academic.naver.com/article.naver?doc_id=597939034'
res = urllib.request.urlopen(url)
print(res.status)
url = 'https://academic.naver.com/article.naver?doc_id=597938953'
res = urllib.request.urlopen(url)
print(res.status)
url = 'https://academic.naver.com/article.naver?doc_id=560009003'
res = urllib.request.urlopen(url)
print(res.status)
url = 'https://academic.naver.com/article.naver?doc_id=597939010'
res = urllib.request.urlopen(url)
print(res.status)
url = 'https://academic.naver.com/article.naver?doc_id=597938949'
res = urllib.request.urlopen(url)
print(res.status)
url = 'https://academic.naver.com/article.naver?doc_id=560008978'
res = urllib.request.urlopen(url)
print(res.status)
url = 'https://academic.naver.com/article.naver?doc_id=597939027'
res = urllib.request.urlopen(url)
print(res.status)
url = 'https://academic.naver.com/article.naver?doc_id=597939027'
res = urllib.request.urlopen(url)
print(res.status)
url = 'https://academic.naver.com/article.naver?doc_id=597939002'
res = urllib.request.urlopen(url)
print(res.status)
url = 'https://academic.naver.com/article.naver?doc_id=597939068'
res = urllib.request.urlopen(url)
print(res.status)
url = 'https://academic.naver.com/article.naver?doc_id=560008987'
res = urllib.request.urlopen(url)
print(res.status)
url = 'https://academic.naver.com/article.naver?doc_id=597939074'
res = urllib.request.urlopen(url)
print(res.status)
url = 'https://academic.naver.com/article.naver?doc_id=597939050'
res = urllib.request.urlopen(url)
print(res.status)
url = 'https://academic.naver.com/article.naver?doc_id=560008991'
res = urllib.request.urlopen(url)
print(res.status)
url = 'https://academic.naver.com/article.naver?doc_id=597939085'
res = urllib.request.urlopen(url)
print(res.status)
url = 'https://academic.naver.com/article.naver?doc_id=560008955'
res = urllib.request.urlopen(url)
print(res.status)
url = 'https://academic.naver.com/article.naver?doc_id=597939063'
res = urllib.request.urlopen(url)
print(res.status)
url = 'https://academic.naver.com/article.naver?doc_id=597939033'
res = urllib.request.urlopen(url)
print(res.status)
url = 'https://academic.naver.com/article.naver?doc_id=597938952'
res = urllib.request.urlopen(url)
print(res.status)
url = 'https://academic.naver.com/article.naver?doc_id=597938986'
res = urllib.request.urlopen(url)
print(res.status)
url = 'https://academic.naver.com/article.naver?doc_id=597939048'
res = urllib.request.urlopen(url)
print(res.status)
url = 'https://academic.naver.com/article.naver?doc_id=597939015'
res = urllib.request.urlopen(url)
print(res.status)
url = 'https://academic.naver.com/article.naver?doc_id=597938998'
res = urllib.request.urlopen(url)
print(res.status)
url = 'https://academic.naver.com/article.naver?doc_id=560008985'
res = urllib.request.urlopen(url)
print(res.status)
url = 'https://academic.naver.com/article.naver?doc_id=597938979'
res = urllib.request.urlopen(url)
print(res.status)
url = 'https://academic.naver.com/article.naver?doc_id=560008975'
res = urllib.request.urlopen(url)
print(res.status)
url = 'https://academic.naver.com/article.naver?doc_id=597939061'
res = urllib.request.urlopen(url)
print(res.status)
url = 'https://academic.naver.com/article.naver?doc_id=560008958'
res = urllib.request.urlopen(url)
print(res.status)
url = 'https://academic.naver.com/article.naver?doc_id=597939089'
res = urllib.request.urlopen(url)
print(res.status)
url = 'https://academic.naver.com/article.naver?doc_id=597938960'
res = urllib.request.urlopen(url)
print(res.status)
url = 'https://academic.naver.com/article.naver?doc_id=597938953'
res = urllib.request.urlopen(url)
print(res.status)
url = 'https://academic.naver.com/article.naver?doc_id=597939034'
res = urllib.request.urlopen(url)
print(res.status)
url = 'https://academic.naver.com/article.naver?doc_id=597938953'
res = urllib.request.urlopen(url)
print(res.status)
url = 'https://academic.naver.com/article.naver?doc_id=560009003'
res = urllib.request.urlopen(url)
print(res.status)
url = 'https://academic.naver.com/article.naver?doc_id=597939010'
res = urllib.request.urlopen(url)
print(res.status)
url = 'https://academic.naver.com/article.naver?doc_id=597938949'
res = urllib.request.urlopen(url)
print(res.status)
url = 'https://academic.naver.com/article.naver?doc_id=560008978'
res = urllib.request.urlopen(url)
print(res.status)
url = 'https://academic.naver.com/article.naver?doc_id=597939027'
res = urllib.request.urlopen(url)
print(res.status)
url = 'https://academic.naver.com/article.naver?doc_id=597939027'
res = urllib.request.urlopen(url)
print(res.status)
url = 'https://academic.naver.com/article.naver?doc_id=597939002'
res = urllib.request.urlopen(url)
print(res.status)
url = 'https://academic.naver.com/article.naver?doc_id=597939068'
res = urllib.request.urlopen(url)
print(res.status)
url = 'https://academic.naver.com/article.naver?doc_id=560008987'
res = urllib.request.urlopen(url)
print(res.status)
url = 'https://academic.naver.com/article.naver?doc_id=597939074'
res = urllib.request.urlopen(url)
print(res.status)
url = 'https://academic.naver.com/article.naver?doc_id=597939050'
res = urllib.request.urlopen(url)
print(res.status)
url = 'https://academic.naver.com/article.naver?doc_id=560008991'
res = urllib.request.urlopen(url)
print(res.status)
url = 'https://academic.naver.com/article.naver?doc_id=597939085'
res = urllib.request.urlopen(url)
print(res.status)
url = 'https://academic.naver.com/article.naver?doc_id=560008955'
res = urllib.request.urlopen(url)
print(res.status)
url = 'https://academic.naver.com/article.naver?doc_id=597939063'
res = urllib.request.urlopen(url)
print(res.status)
url = 'https://academic.naver.com/article.naver?doc_id=597939033'
res = urllib.request.urlopen(url)
print(res.status)
url = 'https://academic.naver.com/article.naver?doc_id=597938952'
res = urllib.request.urlopen(url)
print(res.status)
url = 'https://academic.naver.com/article.naver?doc_id=597938986'
res = urllib.request.urlopen(url)
print(res.status)
url = 'https://academic.naver.com/article.naver?doc_id=597939048'
res = urllib.request.urlopen(url)
print(res.status)
url = 'https://academic.naver.com/article.naver?doc_id=597939015'
res = urllib.request.urlopen(url)
print(res.status)
url = 'https://academic.naver.com/article.naver?doc_id=597938998'
res = urllib.request.urlopen(url)
print(res.status)
url = 'https://academic.naver.com/article.naver?doc_id=560008985'
res = urllib.request.urlopen(url)
print(res.status)
url = 'https://academic.naver.com/article.naver?doc_id=597938979'
res = urllib.request.urlopen(url)
print(res.status)
url = 'https://academic.naver.com/article.naver?doc_id=560008975'
res = urllib.request.urlopen(url)
print(res.status)
url = 'https://academic.naver.com/article.naver?doc_id=597939061'
res = urllib.request.urlopen(url)
print(res.status)
url = 'https://academic.naver.com/article.naver?doc_id=560008958'
res = urllib.request.urlopen(url)
print(res.status)
url = 'https://academic.naver.com/article.naver?doc_id=597939089'
res = urllib.request.urlopen(url)
print(res.status)
url = 'https://academic.naver.com/article.naver?doc_id=597938960'
res = urllib.request.urlopen(url)
print(res.status)
url = 'https://academic.naver.com/article.naver?doc_id=597938953'
res = urllib.request.urlopen(url)
print(res.status)
url = 'https://academic.naver.com/article.naver?doc_id=597939034'
res = urllib.request.urlopen(url)
print(res.status)
url = 'https://academic.naver.com/article.naver?doc_id=597938953'
res = urllib.request.urlopen(url)
print(res.status)
url = 'https://academic.naver.com/article.naver?doc_id=560009003'
res = urllib.request.urlopen(url)
print(res.status)
url = 'https://academic.naver.com/article.naver?doc_id=597939010'
res = urllib.request.urlopen(url)
print(res.status)
url = 'https://academic.naver.com/article.naver?doc_id=597938949'
res = urllib.request.urlopen(url)
print(res.status)
url = 'https://academic.naver.com/article.naver?doc_id=560008978'
res = urllib.request.urlopen(url)
print(res.status)
url = 'https://academic.naver.com/article.naver?doc_id=597939027'
res = urllib.request.urlopen(url)
print(res.status)
url = 'https://academic.naver.com/article.naver?doc_id=597939027'
res = urllib.request.urlopen(url)
print(res.status)
url = 'https://academic.naver.com/article.naver?doc_id=597939002'
res = urllib.request.urlopen(url)
print(res.status)
url = 'https://academic.naver.com/article.naver?doc_id=597939068'
res = urllib.request.urlopen(url)
print(res.status)
url = 'https://academic.naver.com/article.naver?doc_id=560008987'
res = urllib.request.urlopen(url)
print(res.status)
url = 'https://academic.naver.com/article.naver?doc_id=597939074'
res = urllib.request.urlopen(url)
print(res.status)
url = 'https://academic.naver.com/article.naver?doc_id=597939050'
res = urllib.request.urlopen(url)
print(res.status)
url = 'https://academic.naver.com/article.naver?doc_id=560008991'
res = urllib.request.urlopen(url)
print(res.status)
url = 'https://academic.naver.com/article.naver?doc_id=597939085'
res = urllib.request.urlopen(url)
print(res.status)
url = 'https://academic.naver.com/article.naver?doc_id=560008955'
res = urllib.request.urlopen(url)
print(res.status)
url = 'https://academic.naver.com/article.naver?doc_id=597939063'
res = urllib.request.urlopen(url)
print(res.status)
url = 'https://academic.naver.com/article.naver?doc_id=597939033'
res = urllib.request.urlopen(url)
print(res.status)
url = 'https://academic.naver.com/article.naver?doc_id=597938952'
res = urllib.request.urlopen(url)
print(res.status)
url = 'https://academic.naver.com/article.naver?doc_id=597938986'
res = urllib.request.urlopen(url)
print(res.status)
url = 'https://academic.naver.com/article.naver?doc_id=597939048'
res = urllib.request.urlopen(url)
print(res.status)
url = 'https://academic.naver.com/article.naver?doc_id=597939015'
res = urllib.request.urlopen(url)
print(res.status)
url = 'https://academic.naver.com/article.naver?doc_id=597938998'
res = urllib.request.urlopen(url)
print(res.status)
url = 'https://academic.naver.com/article.naver?doc_id=560008985'
res = urllib.request.urlopen(url)
print(res.status)
url = 'https://academic.naver.com/article.naver?doc_id=597938979'
res = urllib.request.urlopen(url)
print(res.status)
url = 'https://academic.naver.com/article.naver?doc_id=560008975'
res = urllib.request.urlopen(url)
print(res.status)
url = 'https://academic.naver.com/article.naver?doc_id=597939061'
res = urllib.request.urlopen(url)
print(res.status)
url = 'https://academic.naver.com/article.naver?doc_id=560008958'
res = urllib.request.urlopen(url)
print(res.status)
url = 'https://academic.naver.com/article.naver?doc_id=597939089'
res = urllib.request.urlopen(url)
print(res.status)
url = 'https://academic.naver.com/article.naver?doc_id=597938960'
res = urllib.request.urlopen(url)
print(res.status)
url = 'https://academic.naver.com/article.naver?doc_id=597938953'
res = urllib.request.urlopen(url)
print(res.status)
url = 'https://academic.naver.com/article.naver?doc_id=597939034'
res = urllib.request.urlopen(url)
print(res.status)
url = 'https://academic.naver.com/article.naver?doc_id=597938953'
res = urllib.request.urlopen(url)
print(res.status)
url = 'https://academic.naver.com/article.naver?doc_id=560009003'
res = urllib.request.urlopen(url)
print(res.status)
url = 'https://academic.naver.com/article.naver?doc_id=597939010'
res = urllib.request.urlopen(url)
print(res.status)
url = 'https://academic.naver.com/article.naver?doc_id=597938949'
res = urllib.request.urlopen(url)
print(res.status)
url = 'https://academic.naver.com/article.naver?doc_id=560008978'
res = urllib.request.urlopen(url)
print(res.status)
url = 'https://academic.naver.com/article.naver?doc_id=597939027'
res = urllib.request.urlopen(url)
print(res.status)
url = 'https://academic.naver.com/article.naver?doc_id=597939027'
res = urllib.request.urlopen(url)
print(res.status)
url = 'https://academic.naver.com/article.naver?doc_id=597939002'
res = urllib.request.urlopen(url)
print(res.status)
url = 'https://academic.naver.com/article.naver?doc_id=597939068'
res = urllib.request.urlopen(url)
print(res.status)
url = 'https://academic.naver.com/article.naver?doc_id=560008987'
res = urllib.request.urlopen(url)
print(res.status)
url = 'https://academic.naver.com/article.naver?doc_id=597939074'
res = urllib.request.urlopen(url)
print(res.status)
url = 'https://academic.naver.com/article.naver?doc_id=597939050'
res = urllib.request.urlopen(url)
print(res.status)
url = 'https://academic.naver.com/article.naver?doc_id=560008991'
res = urllib.request.urlopen(url)
print(res.status)
url = 'https://academic.naver.com/article.naver?doc_id=597939085'
res = urllib.request.urlopen(url)
print(res.status)
url = 'https://academic.naver.com/article.naver?doc_id=560008955'
res = urllib.request.urlopen(url)
print(res.status)
url = 'https://academic.naver.com/article.naver?doc_id=597939063'
res = urllib.request.urlopen(url)
print(res.status)
url = 'https://academic.naver.com/article.naver?doc_id=597939033'
res = urllib.request.urlopen(url)
print(res.status)
url = 'https://academic.naver.com/article.naver?doc_id=597938952'
res = urllib.request.urlopen(url)
print(res.status)
url = 'https://academic.naver.com/article.naver?doc_id=597938986'
res = urllib.request.urlopen(url)
print(res.status)
url = 'https://academic.naver.com/article.naver?doc_id=597939048'
res = urllib.request.urlopen(url)
print(res.status)
url = 'https://academic.naver.com/article.naver?doc_id=597939015'
res = urllib.request.urlopen(url)
print(res.status)
url = 'https://academic.naver.com/article.naver?doc_id=597938998'
res = urllib.request.urlopen(url)
print(res.status)
url = 'https://academic.naver.com/article.naver?doc_id=560008985'
res = urllib.request.urlopen(url)
print(res.status)
url = 'https://academic.naver.com/article.naver?doc_id=597938979'
res = urllib.request.urlopen(url)
print(res.status)
url = 'https://academic.naver.com/article.naver?doc_id=560008975'
res = urllib.request.urlopen(url)
print(res.status)
url = 'https://academic.naver.com/article.naver?doc_id=597939061'
res = urllib.request.urlopen(url)
print(res.status)
url = 'https://academic.naver.com/article.naver?doc_id=560008958'
res = urllib.request.urlopen(url)
print(res.status)
url = 'https://academic.naver.com/article.naver?doc_id=597939089'
res = urllib.request.urlopen(url)
print(res.status)
url = 'https://academic.naver.com/article.naver?doc_id=597938960'
res = urllib.request.urlopen(url)
print(res.status)
url = 'https://academic.naver.com/article.naver?doc_id=597938953'
res = urllib.request.urlopen(url)
print(res.status)
url = 'https://academic.naver.com/article.naver?doc_id=597939034'
res = urllib.request.urlopen(url)
print(res.status)
url = 'https://academic.naver.com/article.naver?doc_id=597938953'
res = urllib.request.urlopen(url)
print(res.status)
url = 'https://academic.naver.com/article.naver?doc_id=560009003'
res = urllib.request.urlopen(url)
print(res.status)
url = 'https://academic.naver.com/article.naver?doc_id=597939010'
res = urllib.request.urlopen(url)
print(res.status)
url = 'https://academic.naver.com/article.naver?doc_id=597938949'
res = urllib.request.urlopen(url)
print(res.status)
url = 'https://academic.naver.com/article.naver?doc_id=560008978'
res = urllib.request.urlopen(url)
print(res.status)
url = 'https://academic.naver.com/article.naver?doc_id=597939027'
res = urllib.request.urlopen(url)
print(res.status)
url = 'https://academic.naver.com/article.naver?doc_id=597939027'
res = urllib.request.urlopen(url)
print(res.status)
url = 'https://academic.naver.com/article.naver?doc_id=597939002'
res = urllib.request.urlopen(url)
print(res.status)
url = 'https://academic.naver.com/article.naver?doc_id=597939068'
res = urllib.request.urlopen(url)
print(res.status)
url = 'https://academic.naver.com/article.naver?doc_id=560008987'
res = urllib.request.urlopen(url)
print(res.status)
url = 'https://academic.naver.com/article.naver?doc_id=597939074'
res = urllib.request.urlopen(url)
print(res.status)
url = 'https://academic.naver.com/article.naver?doc_id=597939050'
res = urllib.request.urlopen(url)
print(res.status)
url = 'https://academic.naver.com/article.naver?doc_id=560008991'
res = urllib.request.urlopen(url)
print(res.status)
url = 'https://academic.naver.com/article.naver?doc_id=597939085'
res = urllib.request.urlopen(url)
print(res.status)
url = 'https://academic.naver.com/article.naver?doc_id=560008955'
res = urllib.request.urlopen(url)
print(res.status)
url = 'https://academic.naver.com/article.naver?doc_id=597939063'
res = urllib.request.urlopen(url)
print(res.status)
url = 'https://academic.naver.com/article.naver?doc_id=597939033'
res = urllib.request.urlopen(url)
print(res.status)
url = 'https://academic.naver.com/article.naver?doc_id=597938952'
res = urllib.request.urlopen(url)
print(res.status)
url = 'https://academic.naver.com/article.naver?doc_id=597938986'
res = urllib.request.urlopen(url)
print(res.status)
url = 'https://academic.naver.com/article.naver?doc_id=597939048'
res = urllib.request.urlopen(url)
print(res.status)
url = 'https://academic.naver.com/article.naver?doc_id=597939015'
res = urllib.request.urlopen(url)
print(res.status)
url = 'https://academic.naver.com/article.naver?doc_id=597938998'
res = urllib.request.urlopen(url)
print(res.status)
url = 'https://academic.naver.com/article.naver?doc_id=560008985'
res = urllib.request.urlopen(url)
print(res.status)
url = 'https://academic.naver.com/article.naver?doc_id=597938979'
res = urllib.request.urlopen(url)
print(res.status)
url = 'https://academic.naver.com/article.naver?doc_id=560008975'
res = urllib.request.urlopen(url)
print(res.status)
url = 'https://academic.naver.com/article.naver?doc_id=597939061'
res = urllib.request.urlopen(url)
print(res.status)
url = 'https://academic.naver.com/article.naver?doc_id=560008958'
res = urllib.request.urlopen(url)
print(res.status)
url = 'https://academic.naver.com/article.naver?doc_id=597939089'
res = urllib.request.urlopen(url)
print(res.status)
url = 'https://academic.naver.com/article.naver?doc_id=597938960'
res = urllib.request.urlopen(url)
print(res.status)
url = 'https://academic.naver.com/article.naver?doc_id=597938953'
res = urllib.request.urlopen(url)
print(res.status)
url = 'https://academic.naver.com/article.naver?doc_id=597939034'
res = urllib.request.urlopen(url)
print(res.status)
url = 'https://academic.naver.com/article.naver?doc_id=597938953'
res = urllib.request.urlopen(url)
print(res.status)
url = 'https://academic.naver.com/article.naver?doc_id=560009003'
res = urllib.request.urlopen(url)
print(res.status)
url = 'https://academic.naver.com/article.naver?doc_id=597939010'
res = urllib.request.urlopen(url)
print(res.status)
url = 'https://academic.naver.com/article.naver?doc_id=597938949'
res = urllib.request.urlopen(url)
print(res.status)
url = 'https://academic.naver.com/article.naver?doc_id=560008978'
res = urllib.request.urlopen(url)
print(res.status)
url = 'https://academic.naver.com/article.naver?doc_id=597939027'
res = urllib.request.urlopen(url)
print(res.status)
url = 'https://academic.naver.com/article.naver?doc_id=597939027'
res = urllib.request.urlopen(url)
print(res.status)
url = 'https://academic.naver.com/article.naver?doc_id=597939002'
res = urllib.request.urlopen(url)
print(res.status)
url = 'https://academic.naver.com/article.naver?doc_id=597939068'
res = urllib.request.urlopen(url)
print(res.status)
url = 'https://academic.naver.com/article.naver?doc_id=560008987'
res = urllib.request.urlopen(url)
print(res.status)
url = 'https://academic.naver.com/article.naver?doc_id=597939074'
res = urllib.request.urlopen(url)
print(res.status)
url = 'https://academic.naver.com/article.naver?doc_id=597939050'
res = urllib.request.urlopen(url)
print(res.status)
url = 'https://academic.naver.com/article.naver?doc_id=560008991'
res = urllib.request.urlopen(url)
print(res.status)
url = 'https://academic.naver.com/article.naver?doc_id=597939085'
res = urllib.request.urlopen(url)
print(res.status)
url = 'https://academic.naver.com/article.naver?doc_id=560008955'
res = urllib.request.urlopen(url)
print(res.status)
url = 'https://academic.naver.com/article.naver?doc_id=597939063'
res = urllib.request.urlopen(url)
print(res.status)
url = 'https://academic.naver.com/article.naver?doc_id=597939033'
res = urllib.request.urlopen(url)
print(res.status)
url = 'https://academic.naver.com/article.naver?doc_id=597938952'
res = urllib.request.urlopen(url)
print(res.status)
url = 'https://academic.naver.com/article.naver?doc_id=597938986'
res = urllib.request.urlopen(url)
print(res.status)
url = 'https://academic.naver.com/article.naver?doc_id=597939048'
res = urllib.request.urlopen(url)
print(res.status)
url = 'https://academic.naver.com/article.naver?doc_id=597939015'
res = urllib.request.urlopen(url)
print(res.status)
url = 'https://academic.naver.com/article.naver?doc_id=597938998'
res = urllib.request.urlopen(url)
print(res.status)
url = 'https://academic.naver.com/article.naver?doc_id=560008985'
res = urllib.request.urlopen(url)
print(res.status)
url = 'https://academic.naver.com/article.naver?doc_id=597938979'
res = urllib.request.urlopen(url)
print(res.status)
url = 'https://academic.naver.com/article.naver?doc_id=560008975'
res = urllib.request.urlopen(url)
print(res.status)
url = 'https://academic.naver.com/article.naver?doc_id=597939061'
res = urllib.request.urlopen(url)
print(res.status)
url = 'https://academic.naver.com/article.naver?doc_id=560008958'
res = urllib.request.urlopen(url)
print(res.status)
url = 'https://academic.naver.com/article.naver?doc_id=597939089'
res = urllib.request.urlopen(url)
print(res.status)
url = 'https://academic.naver.com/article.naver?doc_id=597938960'
res = urllib.request.urlopen(url)
print(res.status)
url = 'https://academic.naver.com/article.naver?doc_id=597938953'
res = urllib.request.urlopen(url)
print(res.status)
url = 'https://academic.naver.com/article.naver?doc_id=597939034'
res = urllib.request.urlopen(url)
print(res.status)
url = 'https://academic.naver.com/article.naver?doc_id=597938953'
res = urllib.request.urlopen(url)
print(res.status)
url = 'https://academic.naver.com/article.naver?doc_id=560009003'
res = urllib.request.urlopen(url)
print(res.status)
url = 'https://academic.naver.com/article.naver?doc_id=597939010'
res = urllib.request.urlopen(url)
print(res.status)
url = 'https://academic.naver.com/article.naver?doc_id=597938949'
res = urllib.request.urlopen(url)
print(res.status)
url = 'https://academic.naver.com/article.naver?doc_id=560008978'
res = urllib.request.urlopen(url)
print(res.status)
url = 'https://academic.naver.com/article.naver?doc_id=597939027'
res = urllib.request.urlopen(url)
print(res.status)
url = 'https://academic.naver.com/article.naver?doc_id=597939027'
res = urllib.request.urlopen(url)
print(res.status)
url = 'https://academic.naver.com/article.naver?doc_id=597939002'
res = urllib.request.urlopen(url)
print(res.status)
url = 'https://academic.naver.com/article.naver?doc_id=597939068'
res = urllib.request.urlopen(url)
print(res.status)
url = 'https://academic.naver.com/article.naver?doc_id=560008987'
res = urllib.request.urlopen(url)
print(res.status)
url = 'https://academic.naver.com/article.naver?doc_id=597939074'
res = urllib.request.urlopen(url)
print(res.status)
url = 'https://academic.naver.com/article.naver?doc_id=597939050'
res = urllib.request.urlopen(url)
print(res.status)
url = 'https://academic.naver.com/article.naver?doc_id=560008991'
res = urllib.request.urlopen(url)
print(res.status)
url = 'https://academic.naver.com/article.naver?doc_id=597939085'
res = urllib.request.urlopen(url)
print(res.status)
url = 'https://academic.naver.com/article.naver?doc_id=560008955'
res = urllib.request.urlopen(url)
print(res.status)
url = 'https://academic.naver.com/article.naver?doc_id=597939063'
res = urllib.request.urlopen(url)
print(res.status)
url = 'https://academic.naver.com/article.naver?doc_id=597939033'
res = urllib.request.urlopen(url)
print(res.status)
url = 'https://academic.naver.com/article.naver?doc_id=597938952'
res = urllib.request.urlopen(url)
print(res.status)
url = 'https://academic.naver.com/article.naver?doc_id=597938986'
res = urllib.request.urlopen(url)
print(res.status)
url = 'https://academic.naver.com/article.naver?doc_id=597939048'
res = urllib.request.urlopen(url)
print(res.status)
url = 'https://academic.naver.com/article.naver?doc_id=597939015'
res = urllib.request.urlopen(url)
print(res.status)
url = 'https://academic.naver.com/article.naver?doc_id=597938998'
res = urllib.request.urlopen(url)
print(res.status)
url = 'https://academic.naver.com/article.naver?doc_id=560008985'
res = urllib.request.urlopen(url)
print(res.status)
url = 'https://academic.naver.com/article.naver?doc_id=597938979'
res = urllib.request.urlopen(url)
print(res.status)
url = 'https://academic.naver.com/article.naver?doc_id=560008975'
res = urllib.request.urlopen(url)
print(res.status)
url = 'https://academic.naver.com/article.naver?doc_id=597939061'
res = urllib.request.urlopen(url)
print(res.status)
url = 'https://academic.naver.com/article.naver?doc_id=560008958'
res = urllib.request.urlopen(url)
print(res.status)
url = 'https://academic.naver.com/article.naver?doc_id=597939089'
res = urllib.request.urlopen(url)
print(res.status)
url = 'https://academic.naver.com/article.naver?doc_id=597938960'
res = urllib.request.urlopen(url)
print(res.status)
url = 'https://academic.naver.com/article.naver?doc_id=597938953'
res = urllib.request.urlopen(url)
print(res.status)
url = 'https://academic.naver.com/article.naver?doc_id=597939034'
res = urllib.request.urlopen(url)
print(res.status)
url = 'https://academic.naver.com/article.naver?doc_id=597938953'
res = urllib.request.urlopen(url)
print(res.status)
url = 'https://academic.naver.com/article.naver?doc_id=560009003'
res = urllib.request.urlopen(url)
print(res.status)
url = 'https://academic.naver.com/article.naver?doc_id=597939010'
res = urllib.request.urlopen(url)
print(res.status)
url = 'https://academic.naver.com/article.naver?doc_id=597938949'
res = urllib.request.urlopen(url)
print(res.status)
url = 'https://academic.naver.com/article.naver?doc_id=560008978'
res = urllib.request.urlopen(url)
print(res.status)
url = 'https://academic.naver.com/article.naver?doc_id=597939027'
res = urllib.request.urlopen(url)
print(res.status)
url = 'https://academic.naver.com/article.naver?doc_id=597939027'
res = urllib.request.urlopen(url)
print(res.status)
url = 'https://academic.naver.com/article.naver?doc_id=597939002'
res = urllib.request.urlopen(url)
print(res.status)
url = 'https://academic.naver.com/article.naver?doc_id=597939068'
res = urllib.request.urlopen(url)
print(res.status)
url = 'https://academic.naver.com/article.naver?doc_id=560008987'
res = urllib.request.urlopen(url)
print(res.status)
url = 'https://academic.naver.com/article.naver?doc_id=597939074'
res = urllib.request.urlopen(url)
print(res.status)
url = 'https://academic.naver.com/article.naver?doc_id=597939050'
res = urllib.request.urlopen(url)
print(res.status)
url = 'https://academic.naver.com/article.naver?doc_id=560008991'
res = urllib.request.urlopen(url)
print(res.status)
url = 'https://academic.naver.com/article.naver?doc_id=597939085'
res = urllib.request.urlopen(url)
print(res.status)
url = 'https://academic.naver.com/article.naver?doc_id=560008955'
res = urllib.request.urlopen(url)
print(res.status)
url = 'https://academic.naver.com/article.naver?doc_id=597939063'
res = urllib.request.urlopen(url)
print(res.status)
url = 'https://academic.naver.com/article.naver?doc_id=597939033'
res = urllib.request.urlopen(url)
print(res.status)
url = 'https://academic.naver.com/article.naver?doc_id=597938952'
res = urllib.request.urlopen(url)
print(res.status)
url = 'https://academic.naver.com/article.naver?doc_id=597938986'
res = urllib.request.urlopen(url)
print(res.status)
url = 'https://academic.naver.com/article.naver?doc_id=597939048'
res = urllib.request.urlopen(url)
print(res.status)
url = 'https://academic.naver.com/article.naver?doc_id=597939015'
res = urllib.request.urlopen(url)
print(res.status)
url = 'https://academic.naver.com/article.naver?doc_id=597938998'
res = urllib.request.urlopen(url)
print(res.status)
url = 'https://academic.naver.com/article.naver?doc_id=560008985'
res = urllib.request.urlopen(url)
print(res.status)
url = 'https://academic.naver.com/article.naver?doc_id=597938979'
res = urllib.request.urlopen(url)
print(res.status)
url = 'https://academic.naver.com/article.naver?doc_id=560008975'
res = urllib.request.urlopen(url)
print(res.status)
url = 'https://academic.naver.com/article.naver?doc_id=597939061'
res = urllib.request.urlopen(url)
print(res.status)
url = 'https://academic.naver.com/article.naver?doc_id=560008958'
res = urllib.request.urlopen(url)
print(res.status)
url = 'https://academic.naver.com/article.naver?doc_id=597939089'
res = urllib.request.urlopen(url)
print(res.status)
url = 'https://academic.naver.com/article.naver?doc_id=597938960'
res = urllib.request.urlopen(url)
print(res.status)
url = 'https://academic.naver.com/article.naver?doc_id=597938953'
res = urllib.request.urlopen(url)
print(res.status)
url = 'https://academic.naver.com/article.naver?doc_id=597939034'
res = urllib.request.urlopen(url)
print(res.status)
url = 'https://academic.naver.com/article.naver?doc_id=597938953'
res = urllib.request.urlopen(url)
print(res.status)
url = 'https://academic.naver.com/article.naver?doc_id=560009003'
res = urllib.request.urlopen(url)
print(res.status)
url = 'https://academic.naver.com/article.naver?doc_id=597939010'
res = urllib.request.urlopen(url)
print(res.status)
url = 'https://academic.naver.com/article.naver?doc_id=597938949'
res = urllib.request.urlopen(url)
print(res.status)
url = 'https://academic.naver.com/article.naver?doc_id=560008978'
res = urllib.request.urlopen(url)
print(res.status)
url = 'https://academic.naver.com/article.naver?doc_id=597939027'
res = urllib.request.urlopen(url)
print(res.status)
url = 'https://academic.naver.com/article.naver?doc_id=597939027'
res = urllib.request.urlopen(url)
print(res.status)
url = 'https://academic.naver.com/article.naver?doc_id=597939002'
res = urllib.request.urlopen(url)
print(res.status)
url = 'https://academic.naver.com/article.naver?doc_id=597939068'
res = urllib.request.urlopen(url)
print(res.status)
url = 'https://academic.naver.com/article.naver?doc_id=560008987'
res = urllib.request.urlopen(url)
print(res.status)
url = 'https://academic.naver.com/article.naver?doc_id=597939074'
res = urllib.request.urlopen(url)
print(res.status)
url = 'https://academic.naver.com/article.naver?doc_id=597939050'
res = urllib.request.urlopen(url)
print(res.status)
url = 'https://academic.naver.com/article.naver?doc_id=560008991'
res = urllib.request.urlopen(url)
print(res.status)
url = 'https://academic.naver.com/article.naver?doc_id=597939085'
res = urllib.request.urlopen(url)
print(res.status)
url = 'https://academic.naver.com/article.naver?doc_id=560008955'
res = urllib.request.urlopen(url)
print(res.status)
url = 'https://academic.naver.com/article.naver?doc_id=597939063'
res = urllib.request.urlopen(url)
print(res.status)
url = 'https://academic.naver.com/article.naver?doc_id=597939033'
res = urllib.request.urlopen(url)
print(res.status)
url = 'https://academic.naver.com/article.naver?doc_id=597938952'
res = urllib.request.urlopen(url)
print(res.status)
url = 'https://academic.naver.com/article.naver?doc_id=597938986'
res = urllib.request.urlopen(url)
print(res.status)
url = 'https://academic.naver.com/article.naver?doc_id=597939048'
res = urllib.request.urlopen(url)
print(res.status)
url = 'https://academic.naver.com/article.naver?doc_id=597939015'
res = urllib.request.urlopen(url)
print(res.status)
url = 'https://academic.naver.com/article.naver?doc_id=597938998'
res = urllib.request.urlopen(url)
print(res.status)
url = 'https://academic.naver.com/article.naver?doc_id=560008985'
res = urllib.request.urlopen(url)
print(res.status)
url = 'https://academic.naver.com/article.naver?doc_id=597938979'
res = urllib.request.urlopen(url)
print(res.status)
url = 'https://academic.naver.com/article.naver?doc_id=560008975'
res = urllib.request.urlopen(url)
print(res.status)
url = 'https://academic.naver.com/article.naver?doc_id=597939061'
res = urllib.request.urlopen(url)
print(res.status)
url = 'https://academic.naver.com/article.naver?doc_id=560008958'
res = urllib.request.urlopen(url)
print(res.status)
url = 'https://academic.naver.com/article.naver?doc_id=597939089'
res = urllib.request.urlopen(url)
print(res.status)
url = 'https://academic.naver.com/article.naver?doc_id=597938960'
res = urllib.request.urlopen(url)
print(res.status)
url = 'https://academic.naver.com/article.naver?doc_id=597938953'
res = urllib.request.urlopen(url)
print(res.status)
url = 'https://academic.naver.com/article.naver?doc_id=597939034'
res = urllib.request.urlopen(url)
print(res.status)
url = 'https://academic.naver.com/article.naver?doc_id=597938953'
res = urllib.request.urlopen(url)
print(res.status)
url = 'https://academic.naver.com/article.naver?doc_id=560009003'
res = urllib.request.urlopen(url)
print(res.status)
url = 'https://academic.naver.com/article.naver?doc_id=597939010'
res = urllib.request.urlopen(url)
print(res.status)
url = 'https://academic.naver.com/article.naver?doc_id=597938949'
res = urllib.request.urlopen(url)
print(res.status)
url = 'https://academic.naver.com/article.naver?doc_id=560008978'
res = urllib.request.urlopen(url)
print(res.status)
url = 'https://academic.naver.com/article.naver?doc_id=597939027'
res = urllib.request.urlopen(url)
print(res.status)
url = 'https://academic.naver.com/article.naver?doc_id=597939027'
res = urllib.request.urlopen(url)
print(res.status)
url = 'https://academic.naver.com/article.naver?doc_id=597939002'
res = urllib.request.urlopen(url)
print(res.status)
url = 'https://academic.naver.com/article.naver?doc_id=597939068'
res = urllib.request.urlopen(url)
print(res.status)
url = 'https://academic.naver.com/article.naver?doc_id=560008987'
res = urllib.request.urlopen(url)
print(res.status)
url = 'https://academic.naver.com/article.naver?doc_id=597939074'
res = urllib.request.urlopen(url)
print(res.status)
url = 'https://academic.naver.com/article.naver?doc_id=597939050'
res = urllib.request.urlopen(url)
print(res.status)
url = 'https://academic.naver.com/article.naver?doc_id=560008991'
res = urllib.request.urlopen(url)
print(res.status)
url = 'https://academic.naver.com/article.naver?doc_id=597939085'
res = urllib.request.urlopen(url)
print(res.status)
url = 'https://academic.naver.com/article.naver?doc_id=560008955'
res = urllib.request.urlopen(url)
print(res.status)
url = 'https://academic.naver.com/article.naver?doc_id=597939063'
res = urllib.request.urlopen(url)
print(res.status)
url = 'https://academic.naver.com/article.naver?doc_id=597939033'
res = urllib.request.urlopen(url)
print(res.status)
url = 'https://academic.naver.com/article.naver?doc_id=597938952'
res = urllib.request.urlopen(url)
print(res.status)
url = 'https://academic.naver.com/article.naver?doc_id=597938986'
res = urllib.request.urlopen(url)
print(res.status)
url = 'https://academic.naver.com/article.naver?doc_id=597939048'
res = urllib.request.urlopen(url)
print(res.status)
url = 'https://academic.naver.com/article.naver?doc_id=597939015'
res = urllib.request.urlopen(url)
print(res.status)
url = 'https://academic.naver.com/article.naver?doc_id=597938998'
res = urllib.request.urlopen(url)
print(res.status)
url = 'https://academic.naver.com/article.naver?doc_id=560008985'
res = urllib.request.urlopen(url)
print(res.status)
url = 'https://academic.naver.com/article.naver?doc_id=597938979'
res = urllib.request.urlopen(url)
print(res.status)
url = 'https://academic.naver.com/article.naver?doc_id=560008975'
res = urllib.request.urlopen(url)
print(res.status)
url = 'https://academic.naver.com/article.naver?doc_id=597939061'
res = urllib.request.urlopen(url)
print(res.status)
url = 'https://academic.naver.com/article.naver?doc_id=560008958'
res = urllib.request.urlopen(url)
print(res.status)
url = 'https://academic.naver.com/article.naver?doc_id=597939089'
res = urllib.request.urlopen(url)
print(res.status)
url = 'https://academic.naver.com/article.naver?doc_id=597938960'
res = urllib.request.urlopen(url)
print(res.status)
url = 'https://academic.naver.com/article.naver?doc_id=597938953'
res = urllib.request.urlopen(url)
print(res.status)
url = 'https://academic.naver.com/article.naver?doc_id=597939034'
res = urllib.request.urlopen(url)
print(res.status)
url = 'https://academic.naver.com/article.naver?doc_id=597938953'
res = urllib.request.urlopen(url)
print(res.status)
url = 'https://academic.naver.com/article.naver?doc_id=560009003'
res = urllib.request.urlopen(url)
print(res.status)
url = 'https://academic.naver.com/article.naver?doc_id=597939010'
res = urllib.request.urlopen(url)
print(res.status)
url = 'https://academic.naver.com/article.naver?doc_id=597938949'
res = urllib.request.urlopen(url)
print(res.status)
url = 'https://academic.naver.com/article.naver?doc_id=560008978'
res = urllib.request.urlopen(url)
print(res.status)
url = 'https://academic.naver.com/article.naver?doc_id=597939027'
res = urllib.request.urlopen(url)
print(res.status)
url = 'https://academic.naver.com/article.naver?doc_id=597939027'
res = urllib.request.urlopen(url)
print(res.status)
url = 'https://academic.naver.com/article.naver?doc_id=597939002'
res = urllib.request.urlopen(url)
print(res.status)
url = 'https://academic.naver.com/article.naver?doc_id=597939068'
res = urllib.request.urlopen(url)
print(res.status)
url = 'https://academic.naver.com/article.naver?doc_id=560008987'
res = urllib.request.urlopen(url)
print(res.status)
url = 'https://academic.naver.com/article.naver?doc_id=597939074'
res = urllib.request.urlopen(url)
print(res.status)
url = 'https://academic.naver.com/article.naver?doc_id=597939050'
res = urllib.request.urlopen(url)
print(res.status)
url = 'https://academic.naver.com/article.naver?doc_id=560008991'
res = urllib.request.urlopen(url)
print(res.status)
url = 'https://academic.naver.com/article.naver?doc_id=597939085'
res = urllib.request.urlopen(url)
print(res.status)
url = 'https://academic.naver.com/article.naver?doc_id=560008955'
res = urllib.request.urlopen(url)
print(res.status)
url = 'https://academic.naver.com/article.naver?doc_id=597939063'
res = urllib.request.urlopen(url)
print(res.status)
url = 'https://academic.naver.com/article.naver?doc_id=597939033'
res = urllib.request.urlopen(url)
print(res.status)
url = 'https://academic.naver.com/article.naver?doc_id=597938952'
res = urllib.request.urlopen(url)
print(res.status)
url = 'https://academic.naver.com/article.naver?doc_id=597938986'
res = urllib.request.urlopen(url)
print(res.status)
url = 'https://academic.naver.com/article.naver?doc_id=597939048'
res = urllib.request.urlopen(url)
print(res.status)
url = 'https://academic.naver.com/article.naver?doc_id=597939015'
res = urllib.request.urlopen(url)
print(res.status)
url = 'https://academic.naver.com/article.naver?doc_id=597938998'
res = urllib.request.urlopen(url)
print(res.status)
url = 'https://academic.naver.com/article.naver?doc_id=560008985'
res = urllib.request.urlopen(url)
print(res.status)
url = 'https://academic.naver.com/article.naver?doc_id=597938979'
res = urllib.request.urlopen(url)
print(res.status)
url = 'https://academic.naver.com/article.naver?doc_id=560008975'
res = urllib.request.urlopen(url)
print(res.status)
url = 'https://academic.naver.com/article.naver?doc_id=597939061'
res = urllib.request.urlopen(url)
print(res.status)
url = 'https://academic.naver.com/article.naver?doc_id=560008958'
res = urllib.request.urlopen(url)
print(res.status)
url = 'https://academic.naver.com/article.naver?doc_id=597939089'
res = urllib.request.urlopen(url)
print(res.status)
url = 'https://academic.naver.com/article.naver?doc_id=597938960'
res = urllib.request.urlopen(url)
print(res.status)
url = 'https://academic.naver.com/article.naver?doc_id=597938953'
res = urllib.request.urlopen(url)
print(res.status)
url = 'https://academic.naver.com/article.naver?doc_id=597939034'
res = urllib.request.urlopen(url)
print(res.status)
url = 'https://academic.naver.com/article.naver?doc_id=597938953'
res = urllib.request.urlopen(url)
print(res.status)
url = 'https://academic.naver.com/article.naver?doc_id=560009003'
res = urllib.request.urlopen(url)
print(res.status)
url = 'https://academic.naver.com/article.naver?doc_id=597939010'
res = urllib.request.urlopen(url)
print(res.status)
url = 'https://academic.naver.com/article.naver?doc_id=597938949'
res = urllib.request.urlopen(url)
print(res.status)
url = 'https://academic.naver.com/article.naver?doc_id=560008978'
res = urllib.request.urlopen(url)
print(res.status)
url = 'https://academic.naver.com/article.naver?doc_id=597939027'
res = urllib.request.urlopen(url)
print(res.status)
url = 'https://academic.naver.com/article.naver?doc_id=597939027'
res = urllib.request.urlopen(url)
print(res.status)
url = 'https://academic.naver.com/article.naver?doc_id=597939002'
res = urllib.request.urlopen(url)
print(res.status)
url = 'https://academic.naver.com/article.naver?doc_id=597939068'
res = urllib.request.urlopen(url)
print(res.status)
url = 'https://academic.naver.com/article.naver?doc_id=560008987'
res = urllib.request.urlopen(url)
print(res.status)
url = 'https://academic.naver.com/article.naver?doc_id=597939074'
res = urllib.request.urlopen(url)
print(res.status)
url = 'https://academic.naver.com/article.naver?doc_id=597939050'
res = urllib.request.urlopen(url)
print(res.status)
url = 'https://academic.naver.com/article.naver?doc_id=560008991'
res = urllib.request.urlopen(url)
print(res.status)
url = 'https://academic.naver.com/article.naver?doc_id=597939085'
res = urllib.request.urlopen(url)
print(res.status)
url = 'https://academic.naver.com/article.naver?doc_id=560008955'
res = urllib.request.urlopen(url)
print(res.status)
url = 'https://academic.naver.com/article.naver?doc_id=597939063'
res = urllib.request.urlopen(url)
print(res.status)
url = 'https://academic.naver.com/article.naver?doc_id=597939033'
res = urllib.request.urlopen(url)
print(res.status)
url = 'https://academic.naver.com/article.naver?doc_id=597938952'
res = urllib.request.urlopen(url)
print(res.status)
url = 'https://academic.naver.com/article.naver?doc_id=597938986'
res = urllib.request.urlopen(url)
print(res.status)
url = 'https://academic.naver.com/article.naver?doc_id=597939048'
res = urllib.request.urlopen(url)
print(res.status)
url = 'https://academic.naver.com/article.naver?doc_id=597939015'
res = urllib.request.urlopen(url)
print(res.status)
url = 'https://academic.naver.com/article.naver?doc_id=597938998'
res = urllib.request.urlopen(url)
print(res.status)
url = 'https://academic.naver.com/article.naver?doc_id=560008985'
res = urllib.request.urlopen(url)
print(res.status)
url = 'https://academic.naver.com/article.naver?doc_id=597938979'
res = urllib.request.urlopen(url)
print(res.status)
url = 'https://academic.naver.com/article.naver?doc_id=560008975'
res = urllib.request.urlopen(url)
print(res.status)
url = 'https://academic.naver.com/article.naver?doc_id=597939061'
res = urllib.request.urlopen(url)
print(res.status)
url = 'https://academic.naver.com/article.naver?doc_id=560008958'
res = urllib.request.urlopen(url)
print(res.status)
url = 'https://academic.naver.com/article.naver?doc_id=597939089'
res = urllib.request.urlopen(url)
print(res.status)
url = 'https://academic.naver.com/article.naver?doc_id=597938960'
res = urllib.request.urlopen(url)
print(res.status)
url = 'https://academic.naver.com/article.naver?doc_id=597938953'
res = urllib.request.urlopen(url)
print(res.status)
url = 'https://academic.naver.com/article.naver?doc_id=597939034'
res = urllib.request.urlopen(url)
print(res.status)
url = 'https://academic.naver.com/article.naver?doc_id=597938953'
res = urllib.request.urlopen(url)
print(res.status)
url = 'https://academic.naver.com/article.naver?doc_id=560009003'
res = urllib.request.urlopen(url)
print(res.status)

print("done")
# Out:
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# ...
