# %%
def visit(url,i):
    import urllib.request
    import time
    j = 0
    while j < i :
        j = j + 1
        target = url
        d = urllib.request.urlopen(target)
        print(target, j, "회 접속 ", d.status, " 200 = 정상")
        '''
        print("3")
        time.sleep(1)
        print("2")
        time.sleep(1)
        print("1")
        time.sleep(1)
        print("0")
        '''
    print("DONE")

i = 100
# report
visit("https://www.koica.go.kr/covid19/7982/subview.do?enc=",i)
# video
visit("https://www.koica.go.kr/covid19/7983/subview.do?enc=",i)
# koica actions
visit("https://www.koica.go.kr/covid19/8019/subview.do?enc=",i)
# video
visit("https://www.koica.go.kr/covid19/8020/subview.do?enc=",i)
# report
visit("https://www.koica.go.kr/covid19/7966/subview.do?enc=",i)
# latest updates
visit("https://www.koica.go.kr/covid19/7964/subview.do?enc=",i)
# video clips
visit("https://www.koica.go.kr/covid19/7970/subview.do?enc=",i)
# Out:
# https://www.koica.go.kr/covid19/7982/subview.do?enc= 1 회 접속  200  200 = 정상
# https://www.koica.go.kr/covid19/7982/subview.do?enc= 2 회 접속  200  200 = 정상
# ...
