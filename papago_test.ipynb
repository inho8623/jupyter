# %%
import requests

request_url = "https://openapi.naver.com/v1/papago/n2mt"
text = "Python is an easy to learn, powerful programming language. It has efficient high-level data structures and a simple but effective approach to object-oriented programming. Python’s elegant syntax and dynamic typing, together with its interpreted nature, make it an ideal language for scripting and rapid application development in many areas on most platforms."

headers = {"X-Naver-Client-Id": "발급받은 클라이언트ID를 넣는다", "X-Naver-Client-Secret": "발급받은 클라이언트 Secret을 넣는다"}
params = {"source": "en", "target": "ko", "text": text}
response = requests.post(request_url, headers=headers, data=params)

result = response.json()

print(result)
# Out:
# {'message': {'@type': 'response', '@service': 'naverservice.nmt.proxy', '@version': '1.0.0', 'result': {'srcLangType': 'en', 'tarLangType': 'ko', 'translatedText': '파이톤은 배우기 쉽고 강력한 프로그래밍 언어다. 효율적인 높은 수준의 데이터 구조와 객체 지향 프로그래밍에 대한 단순하지만 효과적인 접근 방식을 가지고 있다. 파이썬의 우아한 구문과 동적 타이핑은 해석된 성격과 함께 대부분의 플랫폼의 많은 영역에서 스크립팅과 신속한 애플리케이션 개발에 이상적인 언어가 되고 있다.', 'engineType': 'UNDEF_MULTI_SENTENCE', 'pivot': None}}}

# %%
import pandas as pd

data = pd.read_csv("report_sample.csv", encoding='cp949')
data
# Out:
#    nation category   sector                                      kortitle  \
# 0  코트디부아르      수원국  기술환경에너지                             ONO 14 전력 네트워크 가동
# 1      몽골     국제기구     공공행정     세계은행, COVID-19 고용안정지원을 위해 2천만불의 양허성 차관 제공
# 2   솔로몬군도     국제기구     긴급구호              ADB, 코로나 19 관련 솔로몬군도로 SBD 2천만 지원
# 3    파키스탄     국제기구       기타  세계은행, 파키스탄의 농업, 사회적 분야에 3억 7천 1백만불 규모의 차관 지원
# 4      네팔      수원국       기타                       Enough is Enough' 운동 확산
# 5     라오스    KOICA     보건의료      지역 내 청소년 역량강화를 위한 낭노이 프로그램 우돔싸이 지역으로 확대
# 6    파라과이      수원국     공공행정             지난 달 예측한 인플레이션율에서 1% 더 낮은 1.5% 전망
# 7     이집트      수원국       기타      코로나19 발생 기간 동안 여성의 고충 1,000% 증가: 국가여성위원회
# 8     르완다      수원국     공공행정                   르완다 2020/21 예산의 10 가지 주요 특징
# 9  중앙아프리카     국제기구     보건의료                       중앙아프리카공화국에 보호마스크 1만개 공수
#
#                                             kormain1  \
# 0  석유, 에너지부 장관은 5월 4일(월), 거주 인구 2,116  규모의 그랑바쌈 지...
# 1  세계은행 이사회는 6.19(금) 몽골의 긴급지원 및 고용안정지원 사업에 대해 규모 ...
# 2       ADB는 코로나 19 관련, 솔로몬군도에 약 2천만 SBD를 지원하기로 결정함.
# 3  세계은행은 파키스탄과 총 금액 3억 7천1백만불의 두 개의 약정에 서명하여 농업분야...
# 4  Enough is Enough' 운동 조직위는  격리시설 및 지역사회에서 일어난 젠...
# 5  라오스 교육체육부와 UNFPA는 코이카의 지원을 받아 지역 청소년들의 역량강화 및 ...
# 6  이따우 마크로 라탐 경제연구소는 소비위축 심화, 일부 소비재 가격 인하 등이 발생할...
# 7  3월 14일부터 여성위원회의 고충사무소가 받은 고충 건수가 1000% 늘었다고 사무...
# 8  Uzziel Ndagijimana 경제기획재정부 장관은 월요일 2020/2021 회...
# 9  플랜인터내셔널은 타 NGO와 협력하여 코로나19 확진자 발생에 직면한 중앙아프리카공...
#
#                                             kormain2  \
# 0   동 전력 네트워크를 통해 149개의 전봇대와 102개의 가로등에 전력이 공급될 예정임.
# 1  이 사업은 COVID-19 위기에 대응하여 △구직자의 취업기회 확대, △소상공인 및...
# 2  해당 지원은 1천만 SBD의 양허성 차관과 1천만 SBD의 원조로 구성되어 있으며,...
# 3  세계은행은 펀잡 주 사업 지역의 빈곤층 취약가정을 대상으로 양질의 보건 서비스 사용...
# 4  본 운동은 또한 코로나 감염 위험에 처한 모든이에 대해 PCR 검사가 시행될 것과 ...
# 5  본 프로그램을 통해 우돔싸이 주 내 나무르군의 청소년을 대상으로 성생식 보건정보, ...
# 6  이는 지난달 보고서에서 전망되었던 예상 인플레이션 2.5%에서 1%가 낮아진 것임....
# 7  코로나19 위기 시작 전, 국가여성위원회 고충사무소는 평균 월 1천~2천건 사이의 ...
# 8  정부 지출은 향후 2~3 년간의 경제 회복 계획과 2017-2024 년의 7 년간의...
# 9  플랜인터내셔널은 1만개의 보호마스크를 내전 피해가 여전한 중앙아프리카공화국의 코로나...
#
#                                             kormain3  \
# 0                                                NaN
# 1                                                NaN
# 2  솔로몬군도 정부는 해당 지원이 코로나 19로 인한 경제지원 및 최전선 인력의 방역교...
# 3  또한 세계은행은 총 2억 1천9백만불 규모의 'KP주 관개 농업 개선 사업'에 1억...
# 4                                                NaN
# 5                                                NaN
# 6  한편 이 보고서는 4-5월중 크레딧 카드, 데빗 카드를 이용한 지불이 각기 50%,...
# 7  그녀는 사무소가 해당 기간 동안 받은 고충 및 요청의 95%가 사회적경제적 요구와 ...
# 8  이번 예산의 주요 특징은 다음과 같음. 1. 조세수익 감소, 2. 개발 예산(총 예...
# 9  지원 화물은 유럽 민간보호 및 인도지원 집행국(ECHO)의 지원 아래 플랜 등이 참...
#
#                                             kormain4  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
# 5                                                NaN
# 6                                                NaN
# 7  압드 엘 모네임은 사무소가 코로나에 감염된 사람들이 코로나 관련 질의 전용 특별 1...
# 8                                                NaN
# 9                                                NaN
#
#                                             kormain5  transtitle  ...  \
# 0                                                NaN         NaN  ...
# 1                                                NaN         NaN  ...
# 2                                                NaN         NaN  ...
# 3                                                NaN         NaN  ...
# 4                                                NaN         NaN  ...
# 5                                                NaN         NaN  ...
# 6                                                NaN         NaN  ...
# 7  그녀는 사무소에서 법적, 사회적, 정신적 상담을 포함한 전문수준의 서비스를 제공한다...         NaN  ...
# 8                                                NaN         NaN  ...
# 9                                                NaN         NaN  ...
#
#                                                main2  \
# 0  This will permit the locality to be connected ...
# 1  The project will provide temporary relief to e...
# 2  The donation compromise of $10 Million concesi...
# 3  These include a $200m Supporting Human Capital...
# 4                                                NaN
# 5  The extended programme is targeting adolescent...
# 6  Compared to 2.5% that they estimated last mont...
# 7  Before the onset of the novel coronavirus (COV...
# 8  The government spending will be aligned with t...
# 9  PlanInternationalhasairlifted10,000protectivem...
#
#                                                main3  \
# 0                                                NaN
# 1                                                NaN
# 2  The $20 Million donation will go towards the G...
# 3  The $171m Khyber Pakhtunkhwa Irrigated Agricul...
# 4                                                NaN
# 5                                                NaN
# 6  The report also adds that credit and debit car...
# 7  She noted that 95% of the complaints and reque...
# 8  1. Tax revenue to reduce, 2. Development budge...
# 9  Theaidcargowassentonahumanitarianflightorganis...
#
#                                                main4  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
# 5                                                NaN
# 6                                                NaN
# 7  Abd El Moneim added that the office has helped...
# 8                                                NaN
# 9                                                NaN
#
#                                                main5               source  \
# 0                                                NaN         Fratmat.info
# 1                                                NaN      www.montsame.mn
# 2                                                NaN    Solomon Star News
# 3                                                NaN             dawn.com
# 4                                                NaN  The Himalayan Times
# 5                                                NaN      Vientiane Times
# 6                                                NaN               아베세 신문
# 7  Abd El Moneim explained that the office provid...     Daily news Egypt
# 8                                                NaN    Newtimes (Online)
# 9                                                NaN           relief web
#
#                                                 link                  writer  \
# 0  https://www.fratmat.info/article/204610/R%C3%A...              박성연 개발협력코디
# 1                 https://montsame.mn/mn/read/229274  사롤 현지직원, 김은지 개발협력코디네이터
# 2  https://www.solomonstarnews.com/index.php/news...    Shenthel Soaki 현지고용원
# 3  https://www.dawn.com/news/1558146/371m-wb-loan...             정여은 개발협력 코디
# 4  https://thehimalayantimes.com/nepal/enough-is-...             이영지 개발코디네이터
# 5  http://www.vientianetimes.org.la/sub-new/VTTim...          김혜미 개발협력 코디네이터
# 6  https://www.abc.com.py/edicion-impresa/economi...               김진철 코디네이터
# 7  https://wwww.dailynewssegypt.com/2020/06/28/10...                  임지은 코디
# 8  https://www.newtimes.co.rw/news/10-key-highlig...              이경철 개발협력코디
# 9  https://reliefweb.int/report/central-african-r...                  연제호 소장
#
#         reviewer        date covid19
# 0         서동성 소장  2020-05-06     NaN
# 1        우동완 부소장  2020-06-23      해당
# 2  박성홍 WFK 코디네이터  2020-06-26      해당
# 3        최준호 부소장  2020-05-19     NaN
# 4        최종성 부소장  2020-06-21      해당
# 5        여원영 부소장  2020-06-17     NaN
# 6         신만식 소장  2020-06-11      해당
# 7         오연금 소장  2020-06-30      해당
# 8         이병화 소장  2020-06-23     NaN
# 9         연제호 소장  2020-05-08      해당
#
# [10 rows x 27 columns]

# %%
df = pd.DataFrame(data)
df
# Out:
#    nation category   sector                                      kortitle  \
# 0  코트디부아르      수원국  기술환경에너지                             ONO 14 전력 네트워크 가동
# 1      몽골     국제기구     공공행정     세계은행, COVID-19 고용안정지원을 위해 2천만불의 양허성 차관 제공
# 2   솔로몬군도     국제기구     긴급구호              ADB, 코로나 19 관련 솔로몬군도로 SBD 2천만 지원
# 3    파키스탄     국제기구       기타  세계은행, 파키스탄의 농업, 사회적 분야에 3억 7천 1백만불 규모의 차관 지원
# 4      네팔      수원국       기타                       Enough is Enough' 운동 확산
# 5     라오스    KOICA     보건의료      지역 내 청소년 역량강화를 위한 낭노이 프로그램 우돔싸이 지역으로 확대
# 6    파라과이      수원국     공공행정             지난 달 예측한 인플레이션율에서 1% 더 낮은 1.5% 전망
# 7     이집트      수원국       기타      코로나19 발생 기간 동안 여성의 고충 1,000% 증가: 국가여성위원회
# 8     르완다      수원국     공공행정                   르완다 2020/21 예산의 10 가지 주요 특징
# 9  중앙아프리카     국제기구     보건의료                       중앙아프리카공화국에 보호마스크 1만개 공수
#
#                                             kormain1  \
# 0  석유, 에너지부 장관은 5월 4일(월), 거주 인구 2,116  규모의 그랑바쌈 지...
# 1  세계은행 이사회는 6.19(금) 몽골의 긴급지원 및 고용안정지원 사업에 대해 규모 ...
# 2       ADB는 코로나 19 관련, 솔로몬군도에 약 2천만 SBD를 지원하기로 결정함.
# 3  세계은행은 파키스탄과 총 금액 3억 7천1백만불의 두 개의 약정에 서명하여 농업분야...
# 4  Enough is Enough' 운동 조직위는  격리시설 및 지역사회에서 일어난 젠...
# 5  라오스 교육체육부와 UNFPA는 코이카의 지원을 받아 지역 청소년들의 역량강화 및 ...
# 6  이따우 마크로 라탐 경제연구소는 소비위축 심화, 일부 소비재 가격 인하 등이 발생할...
# 7  3월 14일부터 여성위원회의 고충사무소가 받은 고충 건수가 1000% 늘었다고 사무...
# 8  Uzziel Ndagijimana 경제기획재정부 장관은 월요일 2020/2021 회...
# 9  플랜인터내셔널은 타 NGO와 협력하여 코로나19 확진자 발생에 직면한 중앙아프리카공...
#
#                                             kormain2  \
# 0   동 전력 네트워크를 통해 149개의 전봇대와 102개의 가로등에 전력이 공급될 예정임.
# 1  이 사업은 COVID-19 위기에 대응하여 △구직자의 취업기회 확대, △소상공인 및...
# 2  해당 지원은 1천만 SBD의 양허성 차관과 1천만 SBD의 원조로 구성되어 있으며,...
# 3  세계은행은 펀잡 주 사업 지역의 빈곤층 취약가정을 대상으로 양질의 보건 서비스 사용...
# 4  본 운동은 또한 코로나 감염 위험에 처한 모든이에 대해 PCR 검사가 시행될 것과 ...
# 5  본 프로그램을 통해 우돔싸이 주 내 나무르군의 청소년을 대상으로 성생식 보건정보, ...
# 6  이는 지난달 보고서에서 전망되었던 예상 인플레이션 2.5%에서 1%가 낮아진 것임....
# 7  코로나19 위기 시작 전, 국가여성위원회 고충사무소는 평균 월 1천~2천건 사이의 ...
# 8  정부 지출은 향후 2~3 년간의 경제 회복 계획과 2017-2024 년의 7 년간의...
# 9  플랜인터내셔널은 1만개의 보호마스크를 내전 피해가 여전한 중앙아프리카공화국의 코로나...
#
#                                             kormain3  \
# 0                                                NaN
# 1                                                NaN
# 2  솔로몬군도 정부는 해당 지원이 코로나 19로 인한 경제지원 및 최전선 인력의 방역교...
# 3  또한 세계은행은 총 2억 1천9백만불 규모의 'KP주 관개 농업 개선 사업'에 1억...
# 4                                                NaN
# 5                                                NaN
# 6  한편 이 보고서는 4-5월중 크레딧 카드, 데빗 카드를 이용한 지불이 각기 50%,...
# 7  그녀는 사무소가 해당 기간 동안 받은 고충 및 요청의 95%가 사회적경제적 요구와 ...
# 8  이번 예산의 주요 특징은 다음과 같음. 1. 조세수익 감소, 2. 개발 예산(총 예...
# 9  지원 화물은 유럽 민간보호 및 인도지원 집행국(ECHO)의 지원 아래 플랜 등이 참...
#
#                                             kormain4  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
# 5                                                NaN
# 6                                                NaN
# 7  압드 엘 모네임은 사무소가 코로나에 감염된 사람들이 코로나 관련 질의 전용 특별 1...
# 8                                                NaN
# 9                                                NaN
#
#                                             kormain5  transtitle  ...  \
# 0                                                NaN         NaN  ...
# 1                                                NaN         NaN  ...
# 2                                                NaN         NaN  ...
# 3                                                NaN         NaN  ...
# 4                                                NaN         NaN  ...
# 5                                                NaN         NaN  ...
# 6                                                NaN         NaN  ...
# 7  그녀는 사무소에서 법적, 사회적, 정신적 상담을 포함한 전문수준의 서비스를 제공한다...         NaN  ...
# 8                                                NaN         NaN  ...
# 9                                                NaN         NaN  ...
#
#                                                main2  \
# 0  This will permit the locality to be connected ...
# 1  The project will provide temporary relief to e...
# 2  The donation compromise of $10 Million concesi...
# 3  These include a $200m Supporting Human Capital...
# 4                                                NaN
# 5  The extended programme is targeting adolescent...
# 6  Compared to 2.5% that they estimated last mont...
# 7  Before the onset of the novel coronavirus (COV...
# 8  The government spending will be aligned with t...
# 9  PlanInternationalhasairlifted10,000protectivem...
#
#                                                main3  \
# 0                                                NaN
# 1                                                NaN
# 2  The $20 Million donation will go towards the G...
# 3  The $171m Khyber Pakhtunkhwa Irrigated Agricul...
# 4                                                NaN
# 5                                                NaN
# 6  The report also adds that credit and debit car...
# 7  She noted that 95% of the complaints and reque...
# 8  1. Tax revenue to reduce, 2. Development budge...
# 9  Theaidcargowassentonahumanitarianflightorganis...
#
#                                                main4  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
# 5                                                NaN
# 6                                                NaN
# 7  Abd El Moneim added that the office has helped...
# 8                                                NaN
# 9                                                NaN
#
#                                                main5               source  \
# 0                                                NaN         Fratmat.info
# 1                                                NaN      www.montsame.mn
# 2                                                NaN    Solomon Star News
# 3                                                NaN             dawn.com
# 4                                                NaN  The Himalayan Times
# 5                                                NaN      Vientiane Times
# 6                                                NaN               아베세 신문
# 7  Abd El Moneim explained that the office provid...     Daily news Egypt
# 8                                                NaN    Newtimes (Online)
# 9                                                NaN           relief web
#
#                                                 link                  writer  \
# 0  https://www.fratmat.info/article/204610/R%C3%A...              박성연 개발협력코디
# 1                 https://montsame.mn/mn/read/229274  사롤 현지직원, 김은지 개발협력코디네이터
# 2  https://www.solomonstarnews.com/index.php/news...    Shenthel Soaki 현지고용원
# 3  https://www.dawn.com/news/1558146/371m-wb-loan...             정여은 개발협력 코디
# 4  https://thehimalayantimes.com/nepal/enough-is-...             이영지 개발코디네이터
# 5  http://www.vientianetimes.org.la/sub-new/VTTim...          김혜미 개발협력 코디네이터
# 6  https://www.abc.com.py/edicion-impresa/economi...               김진철 코디네이터
# 7  https://wwww.dailynewssegypt.com/2020/06/28/10...                  임지은 코디
# 8  https://www.newtimes.co.rw/news/10-key-highlig...              이경철 개발협력코디
# 9  https://reliefweb.int/report/central-african-r...                  연제호 소장
#
#         reviewer        date covid19
# 0         서동성 소장  2020-05-06     NaN
# 1        우동완 부소장  2020-06-23      해당
# 2  박성홍 WFK 코디네이터  2020-06-26      해당
# 3        최준호 부소장  2020-05-19     NaN
# 4        최종성 부소장  2020-06-21      해당
# 5        여원영 부소장  2020-06-17     NaN
# 6         신만식 소장  2020-06-11      해당
# 7         오연금 소장  2020-06-30      해당
# 8         이병화 소장  2020-06-23     NaN
# 9         연제호 소장  2020-05-08      해당
#
# [10 rows x 27 columns]

# %%
title_list = df['title']
transtitle_list = df['transtitle']

for i in range(10):
    print(title_list[i])
    print(transtitle_list[i])
# Out:
# "ONO 14" electrical network powered up
# nan
# $20 Million Credit to Support Employment Opportunities, Workers, and Employers in the Wake of COVID-19
# nan
# $20 Million Dollar to fight COVID-19
# nan
# $371m WB loans signed for agriculture, social sectors
# nan
# ‘Enough is Enough’ movement voices concern
# nan
# ‘Nang-Noi’ programme extended in Oudomxay to empower local adolescents
# nan
# 1 percent lower than last month's forecast of inflation at 1.5 percent
# nan
# 1,000% increase in women’s complaints during COVID-19 crisis: NCW
# nan
# 10 key highlights of Rwanda’s 2020/21 budget
# nan
# 10,000 protective masks airlifted into Central African Republic
# nan

# %%
import os
import sys
import urllib.request
import json
client_id = "fK5QSV7gbRhfGy9Q3BoT"
client_secret = "sis62MMLIV"

for i in range(10):
    srcText = title_list[i]
    
    encText = urllib.parse.quote(srcText)
    data = "source=en&target=ko&text=" + encText
    url = "https://openapi.naver.com/v1/papago/n2mt"
    request = urllib.request.Request(url)
    request.add_header("X-Naver-Client-Id",client_id)
    request.add_header("X-Naver-Client-Secret",client_secret)
    response = urllib.request.urlopen(request, data=data.encode("utf-8"))
    rescode = response.getcode()
    if(rescode==200):
        response_body = response.read()
        # print(response_body.decode('utf-8'))
        #json 형 변환
        res = json.loads(response_body.decode('utf-8'))
        #from pprint import pprint
        #pprint(res['message']['result']['translatedText'])
        
        transtitle_list[i] = res['message']['result']['translatedText']
        print(transtitle_list[i])
        
    else:
        print("Error Code:" + rescode)
# Out:
# C:\anaconda3\lib\site-packages\ipykernel_launcher.py:27: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# C:\anaconda3\lib\site-packages\pandas\core\indexing.py:670: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_with_indexer(indexer, value)
# "OO 14" 전기 네트워크 전원 켜짐
# COVID-19를 계기로 고용 기회, 근로자 및 고용주를 지원하기 위한 2천만 달러 신용장
# COVID-19와 싸우기 위해 2천만 달러
# 농업, 사회 부문 3억 7100만 달러의 WB 대출 계약
# '충분히' 운동 목소리 우려
# 지역 청소년들에게 힘을 실어주기 위해 '낭-노이' 프로그램을 오오돔사이에서 확장했다.
# 지난달 물가상승률 전망치(1.5%)보다 1%포인트 낮았다.
# COVID-19 위기 시 여성 불만 1,000% 증가: NCW
# 르완다 2020/21 예산 10가지 주요 사항
# 중앙아프리카공화국으로 공수된 1만여 개의 방호 마스크

# %%
df.to_csv("report_output2.csv", encoding='cp949')

df

# %%
########### 원래 코드 ###########

import os
import sys
import urllib.request
import json
client_id = "fK5QSV7gbRhfGy9Q3BoT"
client_secret = "sis62MMLIV"
 
#번역할 메모장 불러오기
with open('source.txt','r',encoding='utf8') as f:
    srcText = f.read()
 
encText = urllib.parse.quote(srcText)
data = "source=en&target=ko&text=" + encText
url = "https://openapi.naver.com/v1/papago/n2mt"
request = urllib.request.Request(url)
request.add_header("X-Naver-Client-Id",client_id)
request.add_header("X-Naver-Client-Secret",client_secret)
response = urllib.request.urlopen(request, data=data.encode("utf-8"))
rescode = response.getcode()
if(rescode==200):
    response_body = response.read()
    # print(response_body.decode('utf-8'))
 
    #json 형 변환
    res = json.loads(response_body.decode('utf-8'))
    from pprint import pprint
    pprint(res)
 
    #파일 생성
    with open('translate.txt', 'w',encoding='utf8') as f:
        f.write(res['message']['result']['translatedText'])
 
else:
    print("Error Code:" + rescode)
# Out:
# {'message': {'@service': 'naverservice.nmt.proxy',
#              '@type': 'response',
#              '@version': '1.0.0',
#              'result': {'engineType': 'UNDEF_MULTI_SENTENCE',
#                         'pivot': None,
#                         'srcLangType': 'en',
#                         'tarLangType': 'ko',
#                         'translatedText': '독자가 페이지의 레이아웃을 볼 때 읽을 수 있는 페이지의 내용에 '
#                                           '정신이 팔려 있다는 것은 오래 전부터 확립된 사실이다. 로렘 '
#                                           "입섬을 사용하는 요점은 '여기에 내용, 여기에 내용'을 사용하는 "
#                                           '것과 달리 다소 정상적인 글자 분포를 가지고 있어 읽을 수 있는 '
#                                           '영어처럼 보이게 한다는 것이다. 많은 데스크톱 출판 패키지와 웹 '
#                                           '페이지 편집자들은 현재 로렘 입숨을 기본 모델 텍스트로 사용하고 '
#                                           "있으며, '로렘 입숨'을 검색하면 아직 걸음마 단계인 많은 웹 "
#                                           '사이트를 발견할 수 있을 것이다. 여러 가지 버전이 수년에 '
#                                           '걸쳐, 때로는 우연히, 때로는 일부러(주입된 유머 등) 진화한 '
#                                           '것이다.'}}}
