# %%
import os
from PIL import Image

currentPath = os.getcwd()
os.chdir("D:/_이인호_업무폴더_정리/개발협력동향/flag/resize")
print(currentPath)

file_list = os.listdir(currentPath)
print("file_list: {}".format(file_list))

for file in file_list :
    f = "{}".format(file)
    print(f)
    
    basewidth = 40
    img = Image.open(f)
    wpercent = (basewidth/float(image.size[0]))
    hsize = int((float(img.size[1])*float(wpercent)))
    img = img.resize((basewidth, hsize), Image.ANTIALIAS)
    img.save("_resize_"+f)
# Out:
# D:\_이인호_업무폴더_정리\개발협력동향\flag\resize
# file_list: ['AFG.png', 'AGO.png', 'ALB.png', 'andorra-flag-xs.png', 'ARG.png', 'ARM.png', 'ATG.png', 'AUS.png', 'AUT.png', 'AZE.png', 'BDI.png', 'BEL.png', 'BEN.png', 'BFA.png', 'BGD.png', 'BGR.png', 'BHR.png', 'BHS.png', 'BIH.png', 'BLR.png', 'BLZ.png', 'BOL.png', 'BRA.png', 'BRB.png', 'BRN.png', 'BTN.png', 'BWA.png', 'CAF.png', 'CAN.png', 'CHE.png', 'CHL.png', 'CHN.png', 'CIV.png', 'CMR.png', 'COD.png', 'COG.png', 'COL.png', 'COM.png', 'CPV.png', 'CRI.png', 'CUB.png', 'cyprus-flag-xs.png', 'CZE.png', 'DEU.png', 'DJI.png', 'DMA.png', 'DNK.png', 'DOM.png', 'DZA.png', 'ECU.png', 'EGY.png', 'ERI.png', 'ESP.png', 'EST.png', 'ETH.png', 'FIN.png', 'FJI.png', 'FRA.png', 'FSM.png', 'GAB.png', 'GEO.png', 'GHA.png', 'GIN.png', 'GMB.png', 'GNB.png', 'GNQ.png', 'GRC.png', 'GRD.png', 'GTM.png', 'GUY.png', 'HND.png', 'HRV.png', 'HTI.png', 'HUN.png', 'IDN.png', 'IND.png', 'IRL.png', 'IRN.png', 'IRQ.png', 'ISL.png', 'ISR.png', 'ITA.png', 'JAM.png', 'JOR.png', 'JPN.png', 'KAZ.png', 'KEN.png', 'KGZ.png', 'KHM.png', 'KIR.png', 'KNA.png', 'kosovo-flag-xs.png', 'KWT.png', 'LAO.png', 'LBN.png', 'LBR.png', 'LBY.png', 'LCA.png', 'liechtenstein-flag-xs.png', 'LKA.png', 'LSO.png', 'LTU.png', 'LUX.png', 'LVA.png', 'MAR.png', 'MCO.png', 'MDA.png', 'MDG.png', 'MDV.png', 'MEX.png', 'MHL.png', 'MKD.png', 'MLI.png', 'MLT.png', 'MMR.png', 'MNE.png', 'MNG.png', 'MOZ.png', 'MRT.png', 'MUS.png', 'MWI.png', 'MYS.png', 'NAM.png', 'NER.png', 'NGA.png', 'NIC.png', 'NIU.png', 'NLD.png', 'NOR.png', 'north-korea-flag-xs.png', 'NPL.png', 'NRU.png', 'NZL.png', 'OMN.png', 'PAK.png', 'PAN.png', 'PER.png', 'PHL.png', 'PLW.png', 'PNG.png', 'PO.png', 'PRT.png', 'PRY.png', 'qatar-flag-xs.png', 'resizeAFG.png', 'ROU.png', 'RUS.png', 'RWA.png', 'samoa-flag-xs.png', 'san-marino-flag-xs.png', 'SAU.png', 'SDN.png', 'SEN.png', 'seychelles-flag-xs.png', 'singapore-flag-xs.png', 'SLB.png', 'SLE.png', 'SLV.png', 'SOM.png', 'south-korea-flag-xs.png', 'SRB.png', 'SSD.png', 'STP.png', 'SUR.png', 'SVK.png', 'SVN.png', 'SWE.png', 'SWZ.png', 'SYR.png', 'taiwan-flag-xs.png', 'TCD.png', 'TGO.png', 'THA.png', 'TJK.png', 'TKM.png', 'TLS.png', 'TON.png', 'TTO.png', 'TUN.png', 'TUR.png', 'TUV.png', 'TZA.png', 'UGA.png', 'UKR.png', 'united-arab-emirates-flag-xs.png', 'united-kingdom-flag-xs.png', 'united-states-of-america-flag-xs.png', 'URY.png', 'UZB.png', 'vatican-city-flag-xs.png', 'VCT.png', 'VEN.png', 'VNM.png', 'YEM.png', 'ZAF.png', 'ZMB.png', 'ZWE.png']
# AFG.png
# AGO.png
# ALB.png
# andorra-flag-xs.png
# ARG.png
# ARM.png
# ATG.png
# AUS.png
# AUT.png
# AZE.png
# BDI.png
# BEL.png
# BEN.png
# BFA.png
# BGD.png
# BGR.png
# BHR.png
# BHS.png
# BIH.png
# BLR.png
# BLZ.png
# BOL.png
# BRA.png
# BRB.png
# BRN.png
# BTN.png
# BWA.png
# CAF.png
# CAN.png
# CHE.png
# CHL.png
# CHN.png
# CIV.png
# CMR.png
# COD.png
# COG.png
# COL.png
# COM.png
# CPV.png
# CRI.png
# CUB.png
# cyprus-flag-xs.png
# CZE.png
# DEU.png
# DJI.png
# DMA.png
# DNK.png
# DOM.png
# DZA.png
# ECU.png
# EGY.png
# ERI.png
# ESP.png
# EST.png
# ETH.png
# FIN.png
# FJI.png
# FRA.png
# FSM.png
# GAB.png
# GEO.png
# GHA.png
# GIN.png
# GMB.png
# GNB.png
# GNQ.png
# GRC.png
# GRD.png
# GTM.png
# GUY.png
# HND.png
# HRV.png
# HTI.png
# HUN.png
# IDN.png
# IND.png
# IRL.png
# IRN.png
# IRQ.png
# ISL.png
# ISR.png
# ITA.png
# JAM.png
# JOR.png
# JPN.png
# KAZ.png
# KEN.png
# KGZ.png
# KHM.png
# KIR.png
# KNA.png
# kosovo-flag-xs.png
# KWT.png
# LAO.png
# LBN.png
# LBR.png
# LBY.png
# LCA.png
# liechtenstein-flag-xs.png
# LKA.png
# LSO.png
# LTU.png
# LUX.png
# LVA.png
# MAR.png
# MCO.png
# MDA.png
# MDG.png
# MDV.png
# MEX.png
# MHL.png
# MKD.png
# MLI.png
# MLT.png
# MMR.png
# MNE.png
# MNG.png
# MOZ.png
# MRT.png
# MUS.png
# MWI.png
# MYS.png
# NAM.png
# NER.png
# NGA.png
# NIC.png
# NIU.png
# NLD.png
# NOR.png
# north-korea-flag-xs.png
# NPL.png
# NRU.png
# NZL.png
# OMN.png
# PAK.png
# PAN.png
# PER.png
# PHL.png
# PLW.png
# PNG.png
# PO.png
# PRT.png
# PRY.png
# qatar-flag-xs.png
# resizeAFG.png
# ROU.png
# RUS.png
# RWA.png
# samoa-flag-xs.png
# san-marino-flag-xs.png
# SAU.png
# SDN.png
# SEN.png
# seychelles-flag-xs.png
# singapore-flag-xs.png
# SLB.png
# SLE.png
# SLV.png
# SOM.png
# south-korea-flag-xs.png
# SRB.png
# SSD.png
# STP.png
# SUR.png
# SVK.png
# SVN.png
# SWE.png
# SWZ.png
# SYR.png
# taiwan-flag-xs.png
# TCD.png
# TGO.png
# THA.png
# TJK.png
# TKM.png
# TLS.png
# TON.png
# TTO.png
# TUN.png
# TUR.png
# TUV.png
# TZA.png
# UGA.png
# UKR.png
# united-arab-emirates-flag-xs.png
# united-kingdom-flag-xs.png
# united-states-of-america-flag-xs.png
# URY.png
# UZB.png
# vatican-city-flag-xs.png
# VCT.png
# VEN.png
# VNM.png
# YEM.png
# ZAF.png
# ZMB.png
# ZWE.png
